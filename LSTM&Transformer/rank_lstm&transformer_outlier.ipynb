# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import tensorflow as tf
import random
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
SEED = 12
np.random.seed(SEED)
tf.random.set_seed(SEED)
random.seed(SEED)

# %%
# import pandas as pd

# # 기존 데이터 경로
# data_path = r"C:\Users\Yoon\OneDrive\한양대학교\3-2\시계열\Assignment\Project\DB\Final_1h_No Missing.csv"

# # 새로 포함할 Feature 목록
# selected_features = ['inner_temperature', 'outside_temperature', 'wind_speed', 'timestamp', 'cooling_power']

# # 데이터 로드
# df = pd.read_csv(data_path)

# # 선택된 Feature만 포함
# df_selected = df[selected_features]

# # 새로운 파일 저장 경로
# output_path = r"C:\Users\Yoon\OneDrive\한양대학교\3-2\시계열\Assignment\Project\DB\Selected_Features.csv"
# df_selected.to_csv(output_path, index=False)

# output_path

# %%
data_path = r"C:\Users\Yoon\OneDrive\한양대학교\3-2\시계열\Assignment\Project\DB\Clipped_Rank.csv"

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# 데이터 경로 설정
data_path = r"C:\Users\Yoon\OneDrive\한양대학교\3-2\시계열\Assignment\Project\DB\Clipped_Rank.csv"

def load_data(path=data_path):
    """Loads the dataset, drops 'timestamp', and splits into X (features) and Y (target)."""
    df = pd.read_csv(path)
    df = df.drop(columns=['timestamp'])  # 'timestamp' 제거
    X = df.drop(columns=['cooling_power'])  # 입력 변수
    Y = df[['cooling_power']]  # 타겟 변수
    return X, Y



def split_data(X, Y, train_fraq, test_len=108):
    """Splits input X and target Y into train, val, and test sets."""
    if test_len > len(X):
        raise ValueError("test_len cannot be greater than the total number of samples.")
    
    test_slice = len(X) - test_len

    X_test, Y_test = X[test_slice:], Y[test_slice:]
    X_train_val, Y_train_val = X[:test_slice], Y[:test_slice]

    train_size = int(len(X_train_val) * train_fraq)

    X_train, Y_train = X_train_val[:train_size], Y_train_val[:train_size]
    X_val, Y_val = X_train_val[train_size:], Y_train_val[train_size:]

    return (X_train, Y_train), (X_val, Y_val), (X_test, Y_test)


def min_max_scale(train_X, train_Y, val_X, val_Y, test_X, test_Y):
    """Applies MinMax Scaling using only the Train data for fitting."""
    mm_X = MinMaxScaler()
    mm_Y = MinMaxScaler()

    # Fit on Train data only
    train_X_scaled = mm_X.fit_transform(train_X)
    train_Y_scaled = mm_Y.fit_transform(train_Y)

    # Transform Validation and Test data
    val_X_scaled = mm_X.transform(val_X)
    val_Y_scaled = mm_Y.transform(val_Y)
    test_X_scaled = mm_X.transform(test_X)
    test_Y_scaled = mm_Y.transform(test_Y)

    return (train_X_scaled, train_Y_scaled), (val_X_scaled, val_Y_scaled), (test_X_scaled, test_Y_scaled), mm_X, mm_Y


def window_dataset(X, Y, n_steps, n_horizon, batch_size, shuffle_buffer, for_training=True):
    """
    Creates a windowed TensorFlow dataset.
    
    Parameters:
    - X: Input features
    - Y: Target values
    - n_steps: Number of timesteps in input
    - n_horizon: Prediction horizon
    - batch_size: Batch size for the dataset
    - shuffle_buffer: Buffer size for shuffling (applies only for training)
    - for_training: If True, applies shuffling for training data
    
    Returns:
    - A TensorFlow dataset object.
    """
    # Sliding window generation
    ds_X = tf.data.Dataset.from_tensor_slices(X)
    ds_Y = tf.data.Dataset.from_tensor_slices(Y)

    # Apply window
    ds_X = ds_X.window(n_steps, shift=n_horizon, drop_remainder=True).flat_map(lambda x: x.batch(n_steps))
    ds_Y = ds_Y.window(n_horizon, shift=n_horizon, drop_remainder=True).flat_map(lambda x: x.batch(n_horizon))

    # Combine inputs and targets
    ds = tf.data.Dataset.zip((ds_X, ds_Y))

    # Apply shuffle only for training data
    if for_training:
        ds = ds.shuffle(shuffle_buffer)

    # Batch and prefetch
    ds = ds.batch(batch_size).prefetch(1)
    return ds

# %%
def lstm_model(n_steps, n_horizon, n_features, lr):
    """Creates an LSTM model for predicting a single target variable."""

    # Clear any previous session
    tf.keras.backend.clear_session()

    # Build the model
    model = tf.keras.models.Sequential([
        # First LSTM Layer
        tf.keras.layers.LSTM(72, activation='relu', input_shape=(n_steps, n_features), return_sequences=True),
        
        # Second LSTM Layer
        tf.keras.layers.LSTM(48, activation='relu', return_sequences=False),
        
        # Dense Layers for Prediction
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.3),  # Dropout for regularization
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.3),  # Additional Dropout Layer
        
        # Output Layer (single value for n_horizon=1)
        tf.keras.layers.Dense(n_horizon)  # n_horizon=1 for single step prediction
    ], name='lstm')

    # Define loss and optimizer
    loss = tf.keras.losses.Huber()
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)

    # Compile the model
    model.compile(loss=loss, optimizer=optimizer, metrics=['mae'])

    return model

# %%
X, Y = load_data()

# 데이터 분리
(train_X, train_Y), (val_X, val_Y), (test_X, test_Y) = split_data(X, Y, train_fraq=0.82, test_len=651)

# MinMax Scaling
(train_X_scaled, train_Y_scaled), (val_X_scaled, val_Y_scaled), (test_X_scaled, test_Y_scaled), mm_X, mm_Y = min_max_scale(
    train_X, train_Y, val_X, val_Y, test_X, test_Y
)

# TensorFlow Dataset 생성
train_ds = window_dataset(train_X_scaled, train_Y_scaled, n_steps=12, n_horizon=1, batch_size=32, shuffle_buffer=100, for_training=True)
val_ds = window_dataset(val_X_scaled, val_Y_scaled, n_steps=12, n_horizon=1, batch_size=32, shuffle_buffer=0, for_training=False)
test_ds = window_dataset(test_X_scaled, test_Y_scaled, n_steps=12, n_horizon=1, batch_size=32, shuffle_buffer=0, for_training=False)

# %%
# 스케일링 확인
print("Original train_Y range:", train_Y.min(), train_Y.max())
print("Scaled train_Y range:", train_Y_scaled.min(), train_Y_scaled.max())

# 복원 확인
train_Y_restored = mm_Y.inverse_transform(train_Y_scaled)
print("Restored train_Y range:", train_Y_restored.min(), train_Y_restored.max())
# Out:
# Original train_Y range: cooling_power    0.958901
# dtype: float64 cooling_power    30.519911
# dtype: float64
# Scaled train_Y range: 0.0 0.9999999999999999
# Restored train_Y range: 0.958901250000002 30.519911249999996

# %%
print("Original train_X range:", train_X.min(), train_X.max())
print("Scaled train_X range:", train_X_scaled.min(), train_X_scaled.max())

# 복원 확인
train_X_restored = mm_X.inverse_transform(train_X_scaled)
print("Restored train_X range:", train_X_restored.min(), train_X_restored.max())
# Out:
# Original train_X range: inner_temperature      16.552301
# Temp_Difference       -17.574581
# inner_humidity         31.216670
# Humidity_Difference   -40.060000
# outside_temperature    26.910000
# dtype: float64 inner_temperature      37.164170
# Temp_Difference         3.962500
# inner_humidity         82.916670
# Humidity_Difference    29.532495
# outside_temperature    37.815000
# dtype: float64
# Scaled train_X range: 0.0 1.0
# Restored train_X range: -40.06 82.91667

# %%
from tensorflow.keras.callbacks import EarlyStopping

# EarlyStopping 설정
early_stopping = EarlyStopping(
    monitor='val_loss',       # Validation Loss를 모니터링
    patience=30,              # 개선되지 않는 에포크 수 (5번 기다림)
    restore_best_weights=True # 가장 낮은 Validation Loss에서의 가중치 복원
)

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

# # ReduceLROnPlateau 설정
lr_decay = ReduceLROnPlateau(
    monitor='val_loss',       # Validation Loss를 기준으로 Learning Rate 감소
    factor=0.5,               # Learning Rate를 50%로 줄임
    patience=15,               # 개선되지 않는 에포크 수 (5번 기다림)
    min_lr=1e-5               # Learning Rate의 하한값
)

# %%
model_checkpoint = ModelCheckpoint(
    filepath='clipped_best_lstm_rank.keras',  # 저장 경로
    monitor='val_loss',       # 모니터링할 값
    save_best_only=True,      # Best 모델만 저장
    verbose=1
)

# %%
# LSTM 모델 생성
lstm = lstm_model(n_steps=12, n_horizon=1, n_features=train_X_scaled.shape[1], lr=3e-4)

# EarlyStopping 콜백
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# Learning Rate Decay 콜백
lr_decay = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=15, min_lr=1e-5)

# 모델 학습
history = lstm.fit(
    train_ds,
    validation_data=val_ds,
    epochs=300,
    callbacks=[early_stopping, lr_decay, model_checkpoint]  # 콜백 추가
)

# # 테스트 결과 출력
# lstm.evaluate(test_ds)
# Out:
# WARNING:tensorflow:From c:\Users\Yoon\.conda\envs\gpt\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Epoch 1/300
# c:\Users\Yoon\.conda\envs\gpt\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#      90/Unknown 4s 7ms/step - loss: 0.1425 - mae: 0.4676
# c:\Users\Yoon\.conda\envs\gpt\Lib\site-packages\keras\src\trainers\epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 1: val_loss improved from inf to 0.00255, saving model to clipped_best_lstm_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1379 - mae: 0.4562 - val_loss: 0.0025 - val_mae: 0.0535 - learning_rate: 3.0000e-04
# Epoch 2/300
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0442 - mae: 0.2273
# Epoch 2: val_loss did not improve from 0.00255
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0438 - mae: 0.2260 - val_loss: 0.0030 - val_mae: 0.0603 - learning_rate: 3.0000e-04
# Epoch 3/300
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0387 - mae: 0.2129
# Epoch 3: val_loss did not improve from 0.00255
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0384 - mae: 0.2118 - val_loss: 0.0026 - val_mae: 0.0551 - learning_rate: 3.0000e-04
# Epoch 4/300
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0356 - mae: 0.2083
# Epoch 4: val_loss improved from 0.00255 to 0.00206, saving model to clipped_best_lstm_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0352 - mae: 0.2066 - val_loss: 0.0021 - val_mae: 0.0468 - learning_rate: 3.0000e-04
# Epoch 5/300
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0328 - mae: 0.2030
# Epoch 5: val_loss improved from 0.00206 to 0.00134, saving model to clipped_best_lstm_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0327 - mae: 0.2025 - val_loss: 0.0013 - val_mae: 0.0385 - learning_rate: 3.0000e-04
# Epoch 6/300
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0332 - mae: 0.2053
# Epoch 6: val_loss did not improve from 0.00134
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0323 - mae: 0.2021 - val_loss: 0.0014 - val_mae: 0.0421 - learning_rate: 3.0000e-04
# Epoch 7/300
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0295 - mae: 0.1940
# Epoch 7: val_loss did not improve from 0.00134
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0291 - mae: 0.1928 - val_loss: 0.0017 - val_mae: 0.0490 - learning_rate: 3.0000e-04
# Epoch 8/300
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0249 - mae: 0.1735
# Epoch 8: val_loss improved from 0.00134 to 0.00127, saving model to clipped_best_lstm_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0249 - mae: 0.1732 - val_loss: 0.0013 - val_mae: 0.0389 - learning_rate: 3.0000e-04
# Epoch 9/300
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0202 - mae: 0.1497
# Epoch 9: val_loss did not improve from 0.00127
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0198 - mae: 0.1477 - val_loss: 0.0013 - val_mae: 0.0375 - learning_rate: 3.0000e-04
# Epoch 10/300
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0207 - mae: 0.1555
# Epoch 10: val_loss improved from 0.00127 to 0.00126, saving model to clipped_best_lstm_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0204 - mae: 0.1544 - val_loss: 0.0013 - val_mae: 0.0369 - learning_rate: 3.0000e-04
# Epoch 11/300
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0245 - mae: 0.1765
# Epoch 11: val_loss did not improve from 0.00126
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0244 - mae: 0.1758 - val_loss: 0.0023 - val_mae: 0.0585 - learning_rate: 3.0000e-04
# Epoch 12/300
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0221 - mae: 0.1673
# Epoch 12: val_loss did not improve from 0.00126
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0217 - mae: 0.1658 - val_loss: 0.0018 - val_mae: 0.0497 - learning_rate: 3.0000e-04
# Epoch 13/300
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0220 - mae: 0.1683
# Epoch 13: val_loss did not improve from 0.00126
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0216 - mae: 0.1671 - val_loss: 0.0026 - val_mae: 0.0632 - learning_rate: 3.0000e-04
# Epoch 14/300
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0201 - mae: 0.1584
# Epoch 14: val_loss did not improve from 0.00126
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0200 - mae: 0.1581 - val_loss: 0.0021 - val_mae: 0.0558 - learning_rate: 3.0000e-04
# Epoch 15/300
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0207 - mae: 0.1616
# Epoch 15: val_loss did not improve from 0.00126
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0206 - mae: 0.1612 - val_loss: 0.0026 - val_mae: 0.0622 - learning_rate: 3.0000e-04
# Epoch 16/300
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0195 - mae: 0.1559
# Epoch 16: val_loss did not improve from 0.00126
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0194 - mae: 0.1554 - val_loss: 0.0020 - val_mae: 0.0537 - learning_rate: 3.0000e-04
# Epoch 17/300
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0188 - mae: 0.1542
# Epoch 17: val_loss did not improve from 0.00126
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0186 - mae: 0.1536 - val_loss: 0.0015 - val_mae: 0.0463 - learning_rate: 3.0000e-04
# Epoch 18/300
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0179 - mae: 0.1459
# Epoch 18: val_loss improved from 0.00126 to 0.00102, saving model to clipped_best_lstm_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0178 - mae: 0.1453 - val_loss: 0.0010 - val_mae: 0.0338 - learning_rate: 3.0000e-04
# Epoch 19/300
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0204 - mae: 0.1609
# Epoch 19: val_loss did not improve from 0.00102
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0200 - mae: 0.1592 - val_loss: 0.0016 - val_mae: 0.0474 - learning_rate: 3.0000e-04
# Epoch 20/300
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0188 - mae: 0.1530
# Epoch 20: val_loss did not improve from 0.00102
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0187 - mae: 0.1526 - val_loss: 0.0011 - val_mae: 0.0367 - learning_rate: 3.0000e-04
# Epoch 21/300
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0183 - mae: 0.1518
# Epoch 21: val_loss did not improve from 0.00102
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0180 - mae: 0.1506 - val_loss: 0.0011 - val_mae: 0.0361 - learning_rate: 3.0000e-04
# Epoch 22/300
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0179 - mae: 0.1493
# Epoch 22: val_loss improved from 0.00102 to 0.00092, saving model to clipped_best_lstm_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0177 - mae: 0.1487 - val_loss: 9.2272e-04 - val_mae: 0.0328 - learning_rate: 3.0000e-04
# Epoch 23/300
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0170 - mae: 0.1466
# Epoch 23: val_loss improved from 0.00092 to 0.00085, saving model to clipped_best_lstm_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0169 - mae: 0.1460 - val_loss: 8.4681e-04 - val_mae: 0.0302 - learning_rate: 3.0000e-04
# Epoch 24/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0173 - mae: 0.1482
# Epoch 24: val_loss did not improve from 0.00085
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0170 - mae: 0.1470 - val_loss: 8.5812e-04 - val_mae: 0.0311 - learning_rate: 3.0000e-04
# Epoch 25/300
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0160 - mae: 0.1422
# Epoch 25: val_loss did not improve from 0.00085
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0158 - mae: 0.1413 - val_loss: 8.5211e-04 - val_mae: 0.0310 - learning_rate: 3.0000e-04
# Epoch 26/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0165 - mae: 0.1431
# Epoch 26: val_loss improved from 0.00085 to 0.00084, saving model to clipped_best_lstm_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0163 - mae: 0.1419 - val_loss: 8.3667e-04 - val_mae: 0.0304 - learning_rate: 3.0000e-04
# Epoch 27/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0163 - mae: 0.1421
# Epoch 27: val_loss improved from 0.00084 to 0.00082, saving model to clipped_best_lstm_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0160 - mae: 0.1408 - val_loss: 8.1769e-04 - val_mae: 0.0293 - learning_rate: 3.0000e-04
# Epoch 28/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0157 - mae: 0.1387
# Epoch 28: val_loss improved from 0.00082 to 0.00081, saving model to clipped_best_lstm_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0154 - mae: 0.1373 - val_loss: 8.1455e-04 - val_mae: 0.0295 - learning_rate: 3.0000e-04
# Epoch 29/300
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0142 - mae: 0.1331
# Epoch 29: val_loss did not improve from 0.00081
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0140 - mae: 0.1316 - val_loss: 8.2129e-04 - val_mae: 0.0293 - learning_rate: 3.0000e-04
# Epoch 30/300
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0150 - mae: 0.1349
# Epoch 30: val_loss did not improve from 0.00081
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0146 - mae: 0.1329 - val_loss: 8.2396e-04 - val_mae: 0.0290 - learning_rate: 3.0000e-04
# Epoch 31/300
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0135 - mae: 0.1286
# Epoch 31: val_loss improved from 0.00081 to 0.00079, saving model to clipped_best_lstm_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0135 - mae: 0.1283 - val_loss: 7.9320e-04 - val_mae: 0.0293 - learning_rate: 3.0000e-04
# Epoch 32/300
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0125 - mae: 0.1232
# Epoch 32: val_loss improved from 0.00079 to 0.00079, saving model to clipped_best_lstm_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0124 - mae: 0.1229 - val_loss: 7.9034e-04 - val_mae: 0.0286 - learning_rate: 3.0000e-04
# Epoch 33/300
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0120 - mae: 0.1207
# Epoch 33: val_loss did not improve from 0.00079
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0118 - mae: 0.1191 - val_loss: 7.9836e-04 - val_mae: 0.0295 - learning_rate: 3.0000e-04
# Epoch 34/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0118 - mae: 0.1185
# Epoch 34: val_loss improved from 0.00079 to 0.00077, saving model to clipped_best_lstm_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0115 - mae: 0.1172 - val_loss: 7.7412e-04 - val_mae: 0.0289 - learning_rate: 3.0000e-04
# Epoch 35/300
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0112 - mae: 0.1160
# Epoch 35: val_loss improved from 0.00077 to 0.00075, saving model to clipped_best_lstm_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0111 - mae: 0.1152 - val_loss: 7.5383e-04 - val_mae: 0.0281 - learning_rate: 3.0000e-04
# Epoch 36/300
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0101 - mae: 0.1100
# Epoch 36: val_loss improved from 0.00075 to 0.00075, saving model to clipped_best_lstm_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0100 - mae: 0.1095 - val_loss: 7.5115e-04 - val_mae: 0.0278 - learning_rate: 3.0000e-04
# Epoch 37/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0100 - mae: 0.1085
# Epoch 37: val_loss improved from 0.00075 to 0.00074, saving model to clipped_best_lstm_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0098 - mae: 0.1073 - val_loss: 7.3578e-04 - val_mae: 0.0280 - learning_rate: 3.0000e-04
# Epoch 38/300
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0099 - mae: 0.1093
# Epoch 38: val_loss did not improve from 0.00074
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0097 - mae: 0.1077 - val_loss: 9.6643e-04 - val_mae: 0.0325 - learning_rate: 3.0000e-04
# Epoch 39/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0100 - mae: 0.1067
# Epoch 39: val_loss did not improve from 0.00074
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0099 - mae: 0.1055 - val_loss: 7.4345e-04 - val_mae: 0.0283 - learning_rate: 3.0000e-04
# Epoch 40/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0101 - mae: 0.1090
# Epoch 40: val_loss did not improve from 0.00074
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0099 - mae: 0.1077 - val_loss: 7.3990e-04 - val_mae: 0.0275 - learning_rate: 3.0000e-04
# Epoch 41/300
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0100 - mae: 0.1081
# Epoch 41: val_loss improved from 0.00074 to 0.00072, saving model to clipped_best_lstm_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0098 - mae: 0.1073 - val_loss: 7.2381e-04 - val_mae: 0.0271 - learning_rate: 3.0000e-04
# Epoch 42/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0096 - mae: 0.1070
# Epoch 42: val_loss did not improve from 0.00072
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0095 - mae: 0.1057 - val_loss: 7.2817e-04 - val_mae: 0.0273 - learning_rate: 3.0000e-04
# Epoch 43/300
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0098 - mae: 0.1078
# Epoch 43: val_loss did not improve from 0.00072
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0096 - mae: 0.1061 - val_loss: 7.4283e-04 - val_mae: 0.0278 - learning_rate: 3.0000e-04
# Epoch 44/300
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0100 - mae: 0.1080
# Epoch 44: val_loss improved from 0.00072 to 0.00072, saving model to clipped_best_lstm_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0097 - mae: 0.1061 - val_loss: 7.2069e-04 - val_mae: 0.0271 - learning_rate: 3.0000e-04
# Epoch 45/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0096 - mae: 0.1065
# Epoch 45: val_loss did not improve from 0.00072
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0094 - mae: 0.1051 - val_loss: 7.2096e-04 - val_mae: 0.0270 - learning_rate: 3.0000e-04
# Epoch 46/300
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0091 - mae: 0.1031
# Epoch 46: val_loss did not improve from 0.00072
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0090 - mae: 0.1022 - val_loss: 7.2905e-04 - val_mae: 0.0277 - learning_rate: 3.0000e-04
# Epoch 47/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0091 - mae: 0.1024
# Epoch 47: val_loss improved from 0.00072 to 0.00071, saving model to clipped_best_lstm_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0089 - mae: 0.1012 - val_loss: 7.0532e-04 - val_mae: 0.0265 - learning_rate: 3.0000e-04
# Epoch 48/300
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0085 - mae: 0.0998
# Epoch 48: val_loss did not improve from 0.00071
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0084 - mae: 0.0985 - val_loss: 7.3207e-04 - val_mae: 0.0270 - learning_rate: 3.0000e-04
# Epoch 49/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0088 - mae: 0.1011
# Epoch 49: val_loss did not improve from 0.00071
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0086 - mae: 0.1000 - val_loss: 7.4939e-04 - val_mae: 0.0271 - learning_rate: 3.0000e-04
# Epoch 50/300
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0089 - mae: 0.1008
# Epoch 50: val_loss did not improve from 0.00071
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0087 - mae: 0.0994 - val_loss: 7.1240e-04 - val_mae: 0.0271 - learning_rate: 3.0000e-04
# Epoch 51/300
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0087 - mae: 0.1005
# Epoch 51: val_loss did not improve from 0.00071
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0085 - mae: 0.0991 - val_loss: 7.4887e-04 - val_mae: 0.0270 - learning_rate: 3.0000e-04
# Epoch 52/300
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0090 - mae: 0.1012
# Epoch 52: val_loss did not improve from 0.00071
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0089 - mae: 0.1005 - val_loss: 7.1827e-04 - val_mae: 0.0267 - learning_rate: 3.0000e-04
# Epoch 53/300
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0091 - mae: 0.1053
# Epoch 53: val_loss did not improve from 0.00071
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0088 - mae: 0.1033 - val_loss: 7.6643e-04 - val_mae: 0.0303 - learning_rate: 1.5000e-04
# Epoch 54/300
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0070 - mae: 0.0914
# Epoch 54: val_loss improved from 0.00071 to 0.00069, saving model to clipped_best_lstm_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0069 - mae: 0.0908 - val_loss: 6.8801e-04 - val_mae: 0.0275 - learning_rate: 1.5000e-04
# Epoch 55/300
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0066 - mae: 0.0893
# Epoch 55: val_loss did not improve from 0.00069
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0065 - mae: 0.0884 - val_loss: 7.2211e-04 - val_mae: 0.0278 - learning_rate: 1.5000e-04
# Epoch 56/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0069 - mae: 0.0922
# Epoch 56: val_loss did not improve from 0.00069
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0068 - mae: 0.0913 - val_loss: 7.2339e-04 - val_mae: 0.0286 - learning_rate: 1.5000e-04
# Epoch 57/300
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0065 - mae: 0.0881
# Epoch 57: val_loss did not improve from 0.00069
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0064 - mae: 0.0871 - val_loss: 7.1957e-04 - val_mae: 0.0278 - learning_rate: 1.5000e-04
# Epoch 58/300
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0070 - mae: 0.0908
# Epoch 58: val_loss did not improve from 0.00069
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0069 - mae: 0.0896 - val_loss: 7.1656e-04 - val_mae: 0.0281 - learning_rate: 1.5000e-04
# Epoch 59/300
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0068 - mae: 0.0900
# Epoch 59: val_loss did not improve from 0.00069
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0068 - mae: 0.0897 - val_loss: 7.3446e-04 - val_mae: 0.0283 - learning_rate: 1.5000e-04
# Epoch 60/300
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0069 - mae: 0.0907
# Epoch 60: val_loss did not improve from 0.00069
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0068 - mae: 0.0895 - val_loss: 7.5147e-04 - val_mae: 0.0282 - learning_rate: 1.5000e-04
# Epoch 61/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0069 - mae: 0.0896
# Epoch 61: val_loss did not improve from 0.00069
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0068 - mae: 0.0887 - val_loss: 7.4221e-04 - val_mae: 0.0285 - learning_rate: 1.5000e-04
# Epoch 62/300
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0064 - mae: 0.0871
# Epoch 62: val_loss did not improve from 0.00069
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0063 - mae: 0.0861 - val_loss: 7.7223e-04 - val_mae: 0.0287 - learning_rate: 1.5000e-04
# Epoch 63/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0066 - mae: 0.0893
# Epoch 63: val_loss did not improve from 0.00069
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0065 - mae: 0.0884 - val_loss: 7.8623e-04 - val_mae: 0.0288 - learning_rate: 1.5000e-04
# Epoch 64/300
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0066 - mae: 0.0881
# Epoch 64: val_loss did not improve from 0.00069
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0065 - mae: 0.0876 - val_loss: 8.0346e-04 - val_mae: 0.0292 - learning_rate: 1.5000e-04
# Epoch 65/300
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0066 - mae: 0.0879
# Epoch 65: val_loss did not improve from 0.00069
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0065 - mae: 0.0875 - val_loss: 8.0372e-04 - val_mae: 0.0292 - learning_rate: 1.5000e-04
# Epoch 66/300
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0063 - mae: 0.0858
# Epoch 66: val_loss did not improve from 0.00069
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0062 - mae: 0.0849 - val_loss: 8.1096e-04 - val_mae: 0.0297 - learning_rate: 1.5000e-04
# Epoch 67/300
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0064 - mae: 0.0867
# Epoch 67: val_loss did not improve from 0.00069
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0063 - mae: 0.0861 - val_loss: 8.1843e-04 - val_mae: 0.0294 - learning_rate: 1.5000e-04
# Epoch 68/300
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0075 - mae: 0.0966
# Epoch 68: val_loss did not improve from 0.00069
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0073 - mae: 0.0950 - val_loss: 0.0010 - val_mae: 0.0362 - learning_rate: 7.5000e-05
# Epoch 69/300
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0055 - mae: 0.0803
# Epoch 69: val_loss did not improve from 0.00069
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0054 - mae: 0.0801 - val_loss: 9.7607e-04 - val_mae: 0.0344 - learning_rate: 7.5000e-05
# Epoch 70/300
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0056 - mae: 0.0812
# Epoch 70: val_loss did not improve from 0.00069
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0055 - mae: 0.0808 - val_loss: 9.8406e-04 - val_mae: 0.0344 - learning_rate: 7.5000e-05
# Epoch 71/300
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0053 - mae: 0.0791
# Epoch 71: val_loss did not improve from 0.00069
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0052 - mae: 0.0781 - val_loss: 9.9712e-04 - val_mae: 0.0347 - learning_rate: 7.5000e-05
# Epoch 72/300
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0050 - mae: 0.0784
# Epoch 72: val_loss did not improve from 0.00069
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0050 - mae: 0.0784 - val_loss: 9.9333e-04 - val_mae: 0.0346 - learning_rate: 7.5000e-05
# Epoch 73/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0053 - mae: 0.0795
# Epoch 73: val_loss did not improve from 0.00069
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0052 - mae: 0.0790 - val_loss: 9.8440e-04 - val_mae: 0.0343 - learning_rate: 7.5000e-05
# Epoch 74/300
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0054 - mae: 0.0789
# Epoch 74: val_loss did not improve from 0.00069
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0053 - mae: 0.0786 - val_loss: 0.0010 - val_mae: 0.0350 - learning_rate: 7.5000e-05
# Epoch 75/300
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0053 - mae: 0.0789
# Epoch 75: val_loss did not improve from 0.00069
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0052 - mae: 0.0780 - val_loss: 9.7607e-04 - val_mae: 0.0336 - learning_rate: 7.5000e-05
# Epoch 76/300
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0054 - mae: 0.0804
# Epoch 76: val_loss did not improve from 0.00069
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0054 - mae: 0.0800 - val_loss: 0.0010 - val_mae: 0.0345 - learning_rate: 7.5000e-05
# Epoch 77/300
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0052 - mae: 0.0780
# Epoch 77: val_loss did not improve from 0.00069
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0052 - mae: 0.0778 - val_loss: 0.0010 - val_mae: 0.0349 - learning_rate: 7.5000e-05
# Epoch 78/300
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0052 - mae: 0.0773
# Epoch 78: val_loss did not improve from 0.00069
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0051 - mae: 0.0772 - val_loss: 0.0010 - val_mae: 0.0345 - learning_rate: 7.5000e-05
# Epoch 79/300
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0054 - mae: 0.0798
# Epoch 79: val_loss did not improve from 0.00069
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0053 - mae: 0.0788 - val_loss: 9.9293e-04 - val_mae: 0.0338 - learning_rate: 7.5000e-05
# Epoch 80/300
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0056 - mae: 0.0806
# Epoch 80: val_loss did not improve from 0.00069
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0054 - mae: 0.0796 - val_loss: 0.0010 - val_mae: 0.0351 - learning_rate: 7.5000e-05
# Epoch 81/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0050 - mae: 0.0774
# Epoch 81: val_loss did not improve from 0.00069
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0050 - mae: 0.0768 - val_loss: 9.9527e-04 - val_mae: 0.0334 - learning_rate: 7.5000e-05
# Epoch 82/300
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0054 - mae: 0.0792
# Epoch 82: val_loss did not improve from 0.00069
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0053 - mae: 0.0782 - val_loss: 0.0010 - val_mae: 0.0343 - learning_rate: 7.5000e-05
# Epoch 83/300
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0054 - mae: 0.0813
# Epoch 83: val_loss did not improve from 0.00069
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0053 - mae: 0.0803 - val_loss: 0.0013 - val_mae: 0.0405 - learning_rate: 3.7500e-05
# Epoch 84/300
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0046 - mae: 0.0722
# Epoch 84: val_loss did not improve from 0.00069
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0046 - mae: 0.0721 - val_loss: 0.0012 - val_mae: 0.0388 - learning_rate: 3.7500e-05

# %%
# import tensorflow as tf

# # GPU 사용 가능한지 확인
# gpus = tf.config.list_physical_devices('GPU')
# if gpus:
#     print(f"사용 가능한 GPU: {gpus}")
# else:
#     print("GPU를 찾을 수 없습니다. CPU를 사용합니다.")

# %%
# !pip uninstall tensorflow
# !pip install tensorflow

# %%
# !pip install tensorflow-gpu==2.6.0

# %%
# !nvcc --version  # CUDA Toolkit 버전 확인

# %%
# 테스트 데이터셋에서 예측 수행
y_pred_scaled = lstm.predict(test_ds)  # (samples, n_horizon) 형태

# y_pred를 (samples, 1)로 변환
y_pred = y_pred_scaled.reshape(-1, 1)  # 2차원으로 변환

# y_pred의 스케일 복원
y_pred = mm_Y.inverse_transform(y_pred)

# y_true를 TensorFlow Dataset에서 추출 및 스케일 복원
y_true_scaled = np.concatenate([y for x, y in test_ds], axis=0)  # (samples, n_horizon)
y_true = y_true_scaled.reshape(-1, 1)  # 2차원으로 변환
y_true = mm_Y.inverse_transform(y_true)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# MAE (Mean Absolute Error)
mae = mean_absolute_error(y_true, y_pred)

# RMSE (Root Mean Squared Error)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))

# MAPE (Mean Absolute Percentage Error)
mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# 성능 결과 출력
print(f"MAE: {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"MAPE: {mape:.2f}%")
# Out:
# MAE: 1.03
# RMSE: 1.30
# MAPE: 8.85%

# %%
import matplotlib.pyplot as plt

# 샘플 수 선택 (테스트 데이터 일부만 시각화)

plt.figure(figsize=(12, 6))

plt.plot(y_true[:100], label="True Values", marker='o')
plt.plot(y_pred[:100], label="Predictions", marker='x')

plt.title("True vs Predicted Cooling Power")
plt.xlabel("Time Steps")
plt.ylabel("Cooling Power")
plt.legend()
plt.grid()
plt.show()

# %%
class PositionEmbedding(tf.keras.layers.Layer):
    def __init__(self, max_len, embed_dim):
        super().__init__()
        self.pos_embedding = tf.keras.layers.Embedding(input_dim=max_len, output_dim=embed_dim)

    def call(self, inputs):
        positions = tf.range(start=0, limit=tf.shape(inputs)[1], delta=1)
        positions = self.pos_embedding(positions)
        return inputs + positions

# %%
def transformer_model(n_steps, n_horizon, n_features, lr):
    """Creates an optimized Transformer model for time series forecasting."""

    # Clear any previous session
    tf.keras.backend.clear_session()

    # Input Layer
    inputs = tf.keras.layers.Input(shape=(n_steps, n_features))

    # Position Embedding
    position_embedding = PositionEmbedding(max_len=n_steps, embed_dim=n_features)(inputs)

    # Transformer Encoder
    transformer = tf.keras.layers.MultiHeadAttention(num_heads=4, key_dim=64)(position_embedding, position_embedding)
    transformer = tf.keras.layers.LayerNormalization(epsilon=1e-6)(transformer)
    transformer = tf.keras.layers.Dropout(0.1)(transformer)

    # Feed-Forward Network
    ff = tf.keras.layers.Dense(128, activation="relu")(transformer)
    ff = tf.keras.layers.Dropout(0.1)(ff)
    ff = tf.keras.layers.Dense(64, activation="relu")(ff)
    ff = tf.keras.layers.LayerNormalization(epsilon=1e-6)(ff)

    # Global Average Pooling
    pooled = tf.keras.layers.GlobalAveragePooling1D()(ff)

    # Output Layer
    outputs = tf.keras.layers.Dense(n_horizon)(pooled)

    # Build Model
    model = tf.keras.models.Model(inputs=inputs, outputs=outputs, name="transformer")

    # Custom Learning Rate
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate=lr,
        decay_steps=1000,
        decay_rate=0.96,
        staircase=True
    )

    # Compile Model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
                  loss="mse",
                  metrics=["mae"])

    return model

# %%
# EarlyStopping 콜백
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# %%
model_checkpoint = ModelCheckpoint(
    filepath='clipped_best_transformer_rank.keras',  # 저장 경로
    monitor='val_loss',       # 모니터링할 값
    save_best_only=True,      # Best 모델만 저장
    verbose=1
)

# %%
# LSTM 모델 생성
transformer = transformer_model(n_steps=12, n_horizon=1, n_features=train_X_scaled.shape[1], lr=3e-4)

# EarlyStopping 콜백
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# Learning Rate Decay 콜백
lr_decay = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=15, min_lr=1e-5)

# 모델 학습
history_transformer = transformer.fit(
    train_ds,
    validation_data=val_ds,
    epochs=120,
    callbacks=[early_stopping, model_checkpoint]  # 콜백 추가
)
# Out:
# Epoch 1/120
#      87/Unknown 3s 5ms/step - loss: 0.1346 - mae: 0.2468
# c:\Users\Yoon\.conda\envs\gpt\Lib\site-packages\keras\src\trainers\epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 1: val_loss improved from inf to 0.00915, saving model to clipped_best_transformer_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1270 - mae: 0.2386 - val_loss: 0.0091 - val_mae: 0.0793
# Epoch 2/120
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0301 - mae: 0.1389
# Epoch 2: val_loss improved from 0.00915 to 0.00422, saving model to clipped_best_transformer_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0297 - mae: 0.1378 - val_loss: 0.0042 - val_mae: 0.0490
# Epoch 3/120
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0260 - mae: 0.1277
# Epoch 3: val_loss improved from 0.00422 to 0.00366, saving model to clipped_best_transformer_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0258 - mae: 0.1270 - val_loss: 0.0037 - val_mae: 0.0472
# Epoch 4/120
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0279 - mae: 0.1334
# Epoch 4: val_loss did not improve from 0.00366
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0278 - mae: 0.1329 - val_loss: 0.0056 - val_mae: 0.0647
# Epoch 5/120
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0229 - mae: 0.1203
# Epoch 5: val_loss did not improve from 0.00366
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0226 - mae: 0.1191 - val_loss: 0.0053 - val_mae: 0.0634
# Epoch 6/120
# 85/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0198 - mae: 0.1122
# Epoch 6: val_loss did not improve from 0.00366
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0193 - mae: 0.1103 - val_loss: 0.0075 - val_mae: 0.0755
# Epoch 7/120
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0165 - mae: 0.1009
# Epoch 7: val_loss did not improve from 0.00366
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0165 - mae: 0.1007 - val_loss: 0.0059 - val_mae: 0.0638
# Epoch 8/120
# 86/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0172 - mae: 0.1022
# Epoch 8: val_loss did not improve from 0.00366
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0168 - mae: 0.1007 - val_loss: 0.0045 - val_mae: 0.0536
# Epoch 9/120
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0143 - mae: 0.0941
# Epoch 9: val_loss did not improve from 0.00366
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0142 - mae: 0.0934 - val_loss: 0.0042 - val_mae: 0.0522
# Epoch 10/120
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0119 - mae: 0.0835
# Epoch 10: val_loss improved from 0.00366 to 0.00335, saving model to clipped_best_transformer_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0118 - mae: 0.0831 - val_loss: 0.0033 - val_mae: 0.0439
# Epoch 11/120
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0120 - mae: 0.0845
# Epoch 11: val_loss improved from 0.00335 to 0.00320, saving model to clipped_best_transformer_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0119 - mae: 0.0838 - val_loss: 0.0032 - val_mae: 0.0431
# Epoch 12/120
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0121 - mae: 0.0848
# Epoch 12: val_loss improved from 0.00320 to 0.00317, saving model to clipped_best_transformer_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0121 - mae: 0.0844 - val_loss: 0.0032 - val_mae: 0.0435
# Epoch 13/120
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0116 - mae: 0.0836
# Epoch 13: val_loss improved from 0.00317 to 0.00299, saving model to clipped_best_transformer_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0116 - mae: 0.0833 - val_loss: 0.0030 - val_mae: 0.0426
# Epoch 14/120
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0108 - mae: 0.0785
# Epoch 14: val_loss improved from 0.00299 to 0.00296, saving model to clipped_best_transformer_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0107 - mae: 0.0780 - val_loss: 0.0030 - val_mae: 0.0421
# Epoch 15/120
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0110 - mae: 0.0799
# Epoch 15: val_loss did not improve from 0.00296
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0110 - mae: 0.0795 - val_loss: 0.0034 - val_mae: 0.0451
# Epoch 16/120
# 85/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0109 - mae: 0.0782
# Epoch 16: val_loss did not improve from 0.00296
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0108 - mae: 0.0775 - val_loss: 0.0031 - val_mae: 0.0428
# Epoch 17/120
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0106 - mae: 0.0776
# Epoch 17: val_loss did not improve from 0.00296
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0106 - mae: 0.0774 - val_loss: 0.0033 - val_mae: 0.0450
# Epoch 18/120
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0097 - mae: 0.0747
# Epoch 18: val_loss did not improve from 0.00296
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0097 - mae: 0.0744 - val_loss: 0.0033 - val_mae: 0.0448
# Epoch 19/120
# 86/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0097 - mae: 0.0747
# Epoch 19: val_loss did not improve from 0.00296
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0097 - mae: 0.0743 - val_loss: 0.0035 - val_mae: 0.0473
# Epoch 20/120
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0096 - mae: 0.0730
# Epoch 20: val_loss did not improve from 0.00296
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0095 - mae: 0.0727 - val_loss: 0.0035 - val_mae: 0.0464
# Epoch 21/120
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0088 - mae: 0.0683
# Epoch 21: val_loss did not improve from 0.00296
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0088 - mae: 0.0681 - val_loss: 0.0031 - val_mae: 0.0433
# Epoch 22/120
# 86/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0091 - mae: 0.0711
# Epoch 22: val_loss improved from 0.00296 to 0.00278, saving model to clipped_best_transformer_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0091 - mae: 0.0707 - val_loss: 0.0028 - val_mae: 0.0414
# Epoch 23/120
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0088 - mae: 0.0699
# Epoch 23: val_loss did not improve from 0.00278
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0088 - mae: 0.0694 - val_loss: 0.0029 - val_mae: 0.0416
# Epoch 24/120
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0079 - mae: 0.0643
# Epoch 24: val_loss did not improve from 0.00278
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0079 - mae: 0.0642 - val_loss: 0.0030 - val_mae: 0.0407
# Epoch 25/120
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0078 - mae: 0.0635
# Epoch 25: val_loss improved from 0.00278 to 0.00256, saving model to clipped_best_transformer_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0078 - mae: 0.0635 - val_loss: 0.0026 - val_mae: 0.0392
# Epoch 26/120
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0075 - mae: 0.0626
# Epoch 26: val_loss improved from 0.00256 to 0.00249, saving model to clipped_best_transformer_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0074 - mae: 0.0624 - val_loss: 0.0025 - val_mae: 0.0368
# Epoch 27/120
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0074 - mae: 0.0625
# Epoch 27: val_loss did not improve from 0.00249
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0074 - mae: 0.0622 - val_loss: 0.0027 - val_mae: 0.0388
# Epoch 28/120
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0067 - mae: 0.0579
# Epoch 28: val_loss improved from 0.00249 to 0.00210, saving model to clipped_best_transformer_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0067 - mae: 0.0579 - val_loss: 0.0021 - val_mae: 0.0339
# Epoch 29/120
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mae: 0.0605
# Epoch 29: val_loss did not improve from 0.00210
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0071 - mae: 0.0602 - val_loss: 0.0024 - val_mae: 0.0347
# Epoch 30/120
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0068 - mae: 0.0584
# Epoch 30: val_loss did not improve from 0.00210
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0068 - mae: 0.0582 - val_loss: 0.0022 - val_mae: 0.0340
# Epoch 31/120
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0067 - mae: 0.0579
# Epoch 31: val_loss did not improve from 0.00210
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0067 - mae: 0.0578 - val_loss: 0.0023 - val_mae: 0.0345
# Epoch 32/120
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0067 - mae: 0.0570
# Epoch 32: val_loss improved from 0.00210 to 0.00196, saving model to clipped_best_transformer_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0067 - mae: 0.0568 - val_loss: 0.0020 - val_mae: 0.0311
# Epoch 33/120
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0069 - mae: 0.0583
# Epoch 33: val_loss did not improve from 0.00196
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0069 - mae: 0.0582 - val_loss: 0.0022 - val_mae: 0.0338
# Epoch 34/120
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0068 - mae: 0.0576
# Epoch 34: val_loss improved from 0.00196 to 0.00194, saving model to clipped_best_transformer_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0067 - mae: 0.0575 - val_loss: 0.0019 - val_mae: 0.0311
# Epoch 35/120
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0069 - mae: 0.0575
# Epoch 35: val_loss improved from 0.00194 to 0.00194, saving model to clipped_best_transformer_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0069 - mae: 0.0574 - val_loss: 0.0019 - val_mae: 0.0324
# Epoch 36/120
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0073 - mae: 0.0610
# Epoch 36: val_loss did not improve from 0.00194
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0073 - mae: 0.0606 - val_loss: 0.0020 - val_mae: 0.0324
# Epoch 37/120
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0067 - mae: 0.0578
# Epoch 37: val_loss improved from 0.00194 to 0.00185, saving model to clipped_best_transformer_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0066 - mae: 0.0577 - val_loss: 0.0018 - val_mae: 0.0304
# Epoch 38/120
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0073 - mae: 0.0601
# Epoch 38: val_loss did not improve from 0.00185
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0072 - mae: 0.0597 - val_loss: 0.0020 - val_mae: 0.0327
# Epoch 39/120
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0066 - mae: 0.0571
# Epoch 39: val_loss improved from 0.00185 to 0.00171, saving model to clipped_best_transformer_rank.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0066 - mae: 0.0569 - val_loss: 0.0017 - val_mae: 0.0296
# Epoch 40/120
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0073 - mae: 0.0605
# Epoch 40: val_loss did not improve from 0.00171
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0073 - mae: 0.0603 - val_loss: 0.0024 - val_mae: 0.0344
# Epoch 41/120
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0065 - mae: 0.0556
# Epoch 41: val_loss did not improve from 0.00171
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0065 - mae: 0.0554 - val_loss: 0.0019 - val_mae: 0.0312
# Epoch 42/120
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0070 - mae: 0.0584
# Epoch 42: val_loss did not improve from 0.00171
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0069 - mae: 0.0581 - val_loss: 0.0022 - val_mae: 0.0328
# Epoch 43/120
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0061 - mae: 0.0542
# Epoch 43: val_loss did not improve from 0.00171
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0061 - mae: 0.0541 - val_loss: 0.0020 - val_mae: 0.0318
# Epoch 44/120
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0065 - mae: 0.0564
# Epoch 44: val_loss did not improve from 0.00171
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0065 - mae: 0.0562 - val_loss: 0.0017 - val_mae: 0.0298
# Epoch 45/120
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0071 - mae: 0.0594
# Epoch 45: val_loss did not improve from 0.00171
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0071 - mae: 0.0591 - val_loss: 0.0019 - val_mae: 0.0316
# Epoch 46/120
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0067 - mae: 0.0585
# Epoch 46: val_loss did not improve from 0.00171
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0067 - mae: 0.0584 - val_loss: 0.0020 - val_mae: 0.0315
# Epoch 47/120
# 85/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0063 - mae: 0.0564
# Epoch 47: val_loss did not improve from 0.00171
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0063 - mae: 0.0561 - val_loss: 0.0019 - val_mae: 0.0312
# Epoch 48/120
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0064 - mae: 0.0563
# Epoch 48: val_loss did not improve from 0.00171
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0064 - mae: 0.0560 - val_loss: 0.0023 - val_mae: 0.0337
# Epoch 49/120
# 86/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0059 - mae: 0.0539
# Epoch 49: val_loss did not improve from 0.00171
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0059 - mae: 0.0538 - val_loss: 0.0020 - val_mae: 0.0318
# Epoch 50/120
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0063 - mae: 0.0553
# Epoch 50: val_loss did not improve from 0.00171
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0063 - mae: 0.0551 - val_loss: 0.0020 - val_mae: 0.0322
# Epoch 51/120
# 86/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0063 - mae: 0.0557
# Epoch 51: val_loss did not improve from 0.00171
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0062 - mae: 0.0552 - val_loss: 0.0022 - val_mae: 0.0335
# Epoch 52/120
# 86/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0062 - mae: 0.0552
# Epoch 52: val_loss did not improve from 0.00171
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0062 - mae: 0.0549 - val_loss: 0.0022 - val_mae: 0.0349
# Epoch 53/120
# 86/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0059 - mae: 0.0538
# Epoch 53: val_loss did not improve from 0.00171
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0059 - mae: 0.0535 - val_loss: 0.0020 - val_mae: 0.0318
# Epoch 54/120
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0060 - mae: 0.0535
# Epoch 54: val_loss did not improve from 0.00171
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0060 - mae: 0.0534 - val_loss: 0.0019 - val_mae: 0.0312
# Epoch 55/120
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0063 - mae: 0.0544
# Epoch 55: val_loss did not improve from 0.00171
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0062 - mae: 0.0541 - val_loss: 0.0019 - val_mae: 0.0317
# Epoch 56/120
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0060 - mae: 0.0548
# Epoch 56: val_loss did not improve from 0.00171
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0060 - mae: 0.0546 - val_loss: 0.0022 - val_mae: 0.0329
# Epoch 57/120
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0056 - mae: 0.0516
# Epoch 57: val_loss did not improve from 0.00171
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0056 - mae: 0.0516 - val_loss: 0.0021 - val_mae: 0.0320
# Epoch 58/120
# 86/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0058 - mae: 0.0533
# Epoch 58: val_loss did not improve from 0.00171
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0058 - mae: 0.0530 - val_loss: 0.0020 - val_mae: 0.0335
# Epoch 59/120
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0063 - mae: 0.0550
# Epoch 59: val_loss did not improve from 0.00171
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0062 - mae: 0.0548 - val_loss: 0.0020 - val_mae: 0.0320
# Epoch 60/120
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0062 - mae: 0.0555
# Epoch 60: val_loss did not improve from 0.00171
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0062 - mae: 0.0550 - val_loss: 0.0021 - val_mae: 0.0339
# Epoch 61/120
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0060 - mae: 0.0547
# Epoch 61: val_loss did not improve from 0.00171
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0060 - mae: 0.0544 - val_loss: 0.0022 - val_mae: 0.0358
# Epoch 62/120
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0058 - mae: 0.0532
# Epoch 62: val_loss did not improve from 0.00171
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0058 - mae: 0.0530 - val_loss: 0.0021 - val_mae: 0.0353
# Epoch 63/120
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0062 - mae: 0.0554
# Epoch 63: val_loss did not improve from 0.00171
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0062 - mae: 0.0554 - val_loss: 0.0020 - val_mae: 0.0342
# Epoch 64/120
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0061 - mae: 0.0538
# Epoch 64: val_loss did not improve from 0.00171
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0061 - mae: 0.0535 - val_loss: 0.0020 - val_mae: 0.0336
# Epoch 65/120
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0061 - mae: 0.0561
# Epoch 65: val_loss did not improve from 0.00171
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0061 - mae: 0.0557 - val_loss: 0.0023 - val_mae: 0.0363
# Epoch 66/120
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0056 - mae: 0.0514
# Epoch 66: val_loss did not improve from 0.00171
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0056 - mae: 0.0513 - val_loss: 0.0020 - val_mae: 0.0347
# Epoch 67/120
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0061 - mae: 0.0543
# Epoch 67: val_loss did not improve from 0.00171
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0061 - mae: 0.0541 - val_loss: 0.0020 - val_mae: 0.0328
# Epoch 68/120
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0060 - mae: 0.0542
# Epoch 68: val_loss did not improve from 0.00171
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0060 - mae: 0.0539 - val_loss: 0.0022 - val_mae: 0.0350
# Epoch 69/120
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0061 - mae: 0.0554
# Epoch 69: val_loss did not improve from 0.00171
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0061 - mae: 0.0553 - val_loss: 0.0019 - val_mae: 0.0345

# %%
# 테스트 데이터셋에서 예측 수행
y_pred_scaled = transformer.predict(test_ds)  # (samples, n_horizon) 형태

# y_pred를 (samples, 1)로 변환
y_pred = y_pred_scaled.reshape(-1, 1)  # 2차원으로 변환

# y_pred의 스케일 복원
y_pred = mm_Y.inverse_transform(y_pred)

# y_true를 TensorFlow Dataset에서 추출 및 스케일 복원
y_true_scaled = np.concatenate([y for x, y in test_ds], axis=0)  # (samples, n_horizon)
y_true = y_true_scaled.reshape(-1, 1)  # 2차원으로 변환
y_true = mm_Y.inverse_transform(y_true)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
# 성능 평가
from sklearn.metrics import mean_absolute_error, mean_squared_error

# MAE (Mean Absolute Error)
mae = mean_absolute_error(y_true, y_pred)

# RMSE (Root Mean Squared Error)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))

# MAPE (Mean Absolute Percentage Error)
mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# 성능 결과 출력
print(f"Transformer Results")
print(f"MAE: {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"MAPE: {mape:.2f}%")
# Out:
# Transformer Results
# MAE: 0.67
# RMSE: 0.88
# MAPE: 5.31%

# %%
# 시각화
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

# 샘플 수 선택 (테스트 데이터 일부만 시각화)
plt.plot(y_true, label="True Values", marker='o', linestyle='-', alpha=0.7)
plt.plot(y_pred, label="Predictions", marker='x', linestyle='--', alpha=0.7)

plt.title("Transformer: True vs Predicted Cooling Power")
plt.xlabel("Time Steps")
plt.ylabel("Cooling Power")
plt.legend()
plt.grid()
plt.show()

# %%
# 시각화
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

# 샘플 수 선택 (테스트 데이터 일부만 시각화)
plt.plot(y_true[500:600], label="True Values", marker='o', linestyle='-', alpha=0.7)
plt.plot(y_pred[500:600], label="Predictions", marker='x', linestyle='--', alpha=0.7)

plt.title("Transformer: True vs Predicted Cooling Power")
plt.xlabel("Time Steps")
plt.ylabel("Cooling Power")
plt.legend()
plt.grid()
plt.show()

# %%
#### 예측

# %%
import pandas as pd
import numpy as np

# 새로운 데이터셋 경로 설정
new_data_path = r"C:\Users\Yoon\OneDrive\한양대학교\3-2\시계열\Assignment\Project\DB\Predict_final_test_dalat.csv"

# 새로운 데이터셋 로드
def load_new_data_with_timestamp(path=new_data_path):
    """
    Loads the new dataset and retains the 'timestamp' column for final result.
    """
    df = pd.read_csv(path)
    return df

# 새로운 데이터셋 로드
new_data = load_new_data_with_timestamp()

# 'timestamp' 컬럼을 datetime 형식으로 변환
new_data['timestamp'] = pd.to_datetime(new_data['timestamp'])

# 입력 데이터(X)와 타겟 데이터(Y) 분리
X_new = new_data.drop(columns=['timestamp', 'cooling_power'])
Y_new = new_data[['cooling_power']]

# MinMax Scaling 적용 (기존 모델의 Scaler 사용)
X_new_scaled = mm_X.transform(X_new)
Y_new_scaled = mm_Y.transform(Y_new)

# TensorFlow Dataset 생성
new_ds = window_dataset(X_new_scaled, Y_new_scaled,  # Y도 실제 값 사용
                        n_steps=12, n_horizon=1, batch_size=32, shuffle_buffer=0, for_training=False)

# 모델 예측 수행
new_y_pred_scaled = transformer.predict(new_ds)  # 예측 수행
new_y_pred = new_y_pred_scaled.reshape(-1, 1)  # 2차원 변환
new_y_pred = mm_Y.inverse_transform(new_y_pred)  # 스케일 복원

# 실제값 복원
new_y_true_scaled = np.concatenate([y for x, y in new_ds], axis=0)  # TensorFlow Dataset에서 추출
new_y_true = new_y_true_scaled.reshape(-1, 1)  # 2차원 변환
new_y_true = mm_Y.inverse_transform(new_y_true)  # 스케일 복원

# DataFrame 생성
result_df = pd.DataFrame({
    "y_true": new_y_true.flatten(),
    "y_pred": new_y_pred.flatten()
}, index=new_data['timestamp'][:len(new_y_true)])  # 인덱스로 timestamp 설정

# 결과 확인
print(result_df.head())

# 결과를 CSV 파일로 저장
output_path = r"C:\Users\Yoon\OneDrive\한양대학교\3-2\시계열\Assignment\Project\DB\Predicted_Results_Timestamp_dalat.csv"
result_df.to_csv(output_path)

print(f"Predicted results saved to: {output_path}")
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#                        y_true     y_pred
# timestamp
# 2024-11-01 00:00:00  11.08330  10.539058
# 2024-11-01 01:00:00  10.97084  10.534544
# 2024-11-01 02:00:00  10.93638  10.531757
# 2024-11-01 03:00:00  10.86654  10.526118
# 2024-11-01 04:00:00  10.83626  10.507543
# Predicted results saved to: C:\Users\Yoon\OneDrive\한양대학교\3-2\시계열\Assignment\Project\DB\Predicted_Results_Timestamp_dalat.csv
# c:\Users\Yoon\.conda\envs\gpt\Lib\site-packages\keras\src\trainers\epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error

# 예측값과 실제값 시각화
plt.figure(figsize=(10, 6))
plt.plot(new_y_true, label="True Values", color="blue")
plt.plot(new_y_pred, label="Predicted Values", color="orange")
plt.legend()
plt.title("Predicted vs True Values on New Dataset")
plt.xlabel("Sample Index")
plt.ylabel("Cooling Power")
plt.show()

# 성능 평가
mse = mean_squared_error(new_y_true, new_y_pred)
mae = mean_absolute_error(new_y_true, new_y_pred)

print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
# Out:
# Mean Squared Error (MSE): 3.6914526198142252
# Mean Absolute Error (MAE): 1.4807978165453761
