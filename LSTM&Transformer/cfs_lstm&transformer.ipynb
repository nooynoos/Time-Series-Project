# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import tensorflow as tf
import random
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
SEED = 12
np.random.seed(SEED)
tf.random.set_seed(SEED)
random.seed(SEED)

# %%
# import pandas as pd

# # 기존 데이터 경로
# data_path = r"C:\Users\Yoon\OneDrive\한양대학교\3-2\시계열\Assignment\Project\DB\Final_1h_No Missing.csv"

# # 새로 포함할 Feature 목록
# selected_features = ['inner_temperature', 'outside_temperature', 'wind_speed', 'timestamp', 'cooling_power']

# # 데이터 로드
# df = pd.read_csv(data_path)

# # 선택된 Feature만 포함
# df_selected = df[selected_features]

# # 새로운 파일 저장 경로
# output_path = r"C:\Users\Yoon\OneDrive\한양대학교\3-2\시계열\Assignment\Project\DB\Selected_Features.csv"
# df_selected.to_csv(output_path, index=False)

# output_path

# %%
data_path = r"C:\Users\Yoon\OneDrive\한양대학교\3-2\시계열\Assignment\Project\DB\CFS_based_feature.csv"

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# 데이터 경로 설정
data_path = r"C:\Users\Yoon\OneDrive\한양대학교\3-2\시계열\Assignment\Project\DB\CFS_based_feature.csv"

def load_data(path=data_path):
    """Loads the dataset, drops 'timestamp', and splits into X (features) and Y (target)."""
    df = pd.read_csv(path)
    df = df.drop(columns=['timestamp'])  # 'timestamp' 제거
    X = df.drop(columns=['cooling_power'])  # 입력 변수
    Y = df[['cooling_power']]  # 타겟 변수
    return X, Y



def split_data(X, Y, train_fraq, test_len=108):
    """Splits input X and target Y into train, val, and test sets."""
    if test_len > len(X):
        raise ValueError("test_len cannot be greater than the total number of samples.")
    
    test_slice = len(X) - test_len

    X_test, Y_test = X[test_slice:], Y[test_slice:]
    X_train_val, Y_train_val = X[:test_slice], Y[:test_slice]

    train_size = int(len(X_train_val) * train_fraq)

    X_train, Y_train = X_train_val[:train_size], Y_train_val[:train_size]
    X_val, Y_val = X_train_val[train_size:], Y_train_val[train_size:]

    return (X_train, Y_train), (X_val, Y_val), (X_test, Y_test)


def min_max_scale(train_X, train_Y, val_X, val_Y, test_X, test_Y):
    """Applies MinMax Scaling using only the Train data for fitting."""
    mm_X = MinMaxScaler()
    mm_Y = MinMaxScaler()

    # Fit on Train data only
    train_X_scaled = mm_X.fit_transform(train_X)
    train_Y_scaled = mm_Y.fit_transform(train_Y)

    # Transform Validation and Test data
    val_X_scaled = mm_X.transform(val_X)
    val_Y_scaled = mm_Y.transform(val_Y)
    test_X_scaled = mm_X.transform(test_X)
    test_Y_scaled = mm_Y.transform(test_Y)

    return (train_X_scaled, train_Y_scaled), (val_X_scaled, val_Y_scaled), (test_X_scaled, test_Y_scaled), mm_X, mm_Y


def window_dataset(X, Y, n_steps, n_horizon, batch_size, shuffle_buffer, for_training=True):
    """
    Creates a windowed TensorFlow dataset.
    
    Parameters:
    - X: Input features
    - Y: Target values
    - n_steps: Number of timesteps in input
    - n_horizon: Prediction horizon
    - batch_size: Batch size for the dataset
    - shuffle_buffer: Buffer size for shuffling (applies only for training)
    - for_training: If True, applies shuffling for training data
    
    Returns:
    - A TensorFlow dataset object.
    """
    # Sliding window generation
    ds_X = tf.data.Dataset.from_tensor_slices(X)
    ds_Y = tf.data.Dataset.from_tensor_slices(Y)

    # Apply window
    ds_X = ds_X.window(n_steps, shift=n_horizon, drop_remainder=True).flat_map(lambda x: x.batch(n_steps))
    ds_Y = ds_Y.window(n_horizon, shift=n_horizon, drop_remainder=True).flat_map(lambda x: x.batch(n_horizon))

    # Combine inputs and targets
    ds = tf.data.Dataset.zip((ds_X, ds_Y))

    # Apply shuffle only for training data
    if for_training:
        ds = ds.shuffle(shuffle_buffer)

    # Batch and prefetch
    ds = ds.batch(batch_size).prefetch(1)
    return ds

# %%
def lstm_model(n_steps, n_horizon, n_features, lr):
    """Creates an LSTM model for predicting a single target variable."""

    # Clear any previous session
    tf.keras.backend.clear_session()

    # Build the model
    model = tf.keras.models.Sequential([
        # First LSTM Layer
        tf.keras.layers.LSTM(72, activation='relu', input_shape=(n_steps, n_features), return_sequences=True),
        
        # Second LSTM Layer
        tf.keras.layers.LSTM(48, activation='relu', return_sequences=False),
        
        # Dense Layers for Prediction
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.3),  # Dropout for regularization
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.3),  # Additional Dropout Layer
        
        # Output Layer (single value for n_horizon=1)
        tf.keras.layers.Dense(n_horizon)  # n_horizon=1 for single step prediction
    ], name='lstm')

    # Define loss and optimizer
    loss = tf.keras.losses.Huber()
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)

    # Compile the model
    model.compile(loss=loss, optimizer=optimizer, metrics=['mae'])

    return model

# %%
X, Y = load_data()

# 데이터 분리
(train_X, train_Y), (val_X, val_Y), (test_X, test_Y) = split_data(X, Y, train_fraq=0.82, test_len=651)

# MinMax Scaling
(train_X_scaled, train_Y_scaled), (val_X_scaled, val_Y_scaled), (test_X_scaled, test_Y_scaled), mm_X, mm_Y = min_max_scale(
    train_X, train_Y, val_X, val_Y, test_X, test_Y
)

# TensorFlow Dataset 생성
train_ds = window_dataset(train_X_scaled, train_Y_scaled, n_steps=12, n_horizon=1, batch_size=32, shuffle_buffer=100, for_training=True)
val_ds = window_dataset(val_X_scaled, val_Y_scaled, n_steps=12, n_horizon=1, batch_size=32, shuffle_buffer=0, for_training=False)
test_ds = window_dataset(test_X_scaled, test_Y_scaled, n_steps=12, n_horizon=1, batch_size=32, shuffle_buffer=0, for_training=False)

# %%
# 스케일링 확인
print("Original train_Y range:", train_Y.min(), train_Y.max())
print("Scaled train_Y range:", train_Y_scaled.min(), train_Y_scaled.max())

# 복원 확인
train_Y_restored = mm_Y.inverse_transform(train_Y_scaled)
print("Restored train_Y range:", train_Y_restored.min(), train_Y_restored.max())
# Out:
# Original train_Y range: cooling_power    0.0
# dtype: float64 cooling_power    43.81415
# dtype: float64
# Scaled train_Y range: 0.0 1.0
# Restored train_Y range: 0.0 43.81415

# %%
print("Original train_X range:", train_X.min(), train_X.max())
print("Scaled train_X range:", train_X_scaled.min(), train_X_scaled.max())

# 복원 확인
train_X_restored = mm_X.inverse_transform(train_X_scaled)
print("Restored train_X range:", train_X_restored.min(), train_X_restored.max())
# Out:
# Original train_X range: Wind_humidity_Interaction    19.4400
# Temp_Difference             -18.2450
# outside_temperature          26.9100
# rainfall                      0.0000
# inner_temperature            16.2475
# dtype: float64 Wind_humidity_Interaction    811.28700
# Temp_Difference                3.96250
# outside_temperature           38.78000
# rainfall                       7.00000
# inner_temperature             37.16417
# dtype: float64
# Scaled train_X range: 0.0 1.0
# Restored train_X range: -18.245 811.287

# %%
from tensorflow.keras.callbacks import EarlyStopping

# EarlyStopping 설정
early_stopping = EarlyStopping(
    monitor='val_loss',       # Validation Loss를 모니터링
    patience=30,              # 개선되지 않는 에포크 수 (5번 기다림)
    restore_best_weights=True # 가장 낮은 Validation Loss에서의 가중치 복원
)

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

# # ReduceLROnPlateau 설정
lr_decay = ReduceLROnPlateau(
    monitor='val_loss',       # Validation Loss를 기준으로 Learning Rate 감소
    factor=0.8,               # Learning Rate를 50%로 줄임
    patience=15,               # 개선되지 않는 에포크 수 (5번 기다림)
    min_lr=1e-5               # Learning Rate의 하한값
)

# %%
model_checkpoint = ModelCheckpoint(
    filepath='best_lstm_cfs.keras',  # 저장 경로
    monitor='val_loss',       # 모니터링할 값
    save_best_only=True,      # Best 모델만 저장
    verbose=1
)

# %%
# LSTM 모델 생성
lstm = lstm_model(n_steps=12, n_horizon=1, n_features=train_X_scaled.shape[1], lr=3e-4)

# EarlyStopping 콜백
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# Learning Rate Decay 콜백
lr_decay = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=15, min_lr=1e-5)

# 모델 학습
history = lstm.fit(
    train_ds,
    validation_data=val_ds,
    epochs=300,
    callbacks=[early_stopping, lr_decay, model_checkpoint]  # 콜백 추가
)

# # 테스트 결과 출력
# lstm.evaluate(test_ds)
# Out:
# WARNING:tensorflow:From c:\Users\Yoon\.conda\envs\gpt\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Epoch 1/300
# c:\Users\Yoon\.conda\envs\gpt\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#      95/Unknown 3s 6ms/step - loss: 0.0661 - mae: 0.3156
# c:\Users\Yoon\.conda\envs\gpt\Lib\site-packages\keras\src\trainers\epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 1: val_loss improved from inf to 0.00192, saving model to best_lstm_cfs.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.0658 - mae: 0.3143 - val_loss: 0.0019 - val_mae: 0.0473 - learning_rate: 3.0000e-04
# Epoch 2/300
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0221 - mae: 0.1614
# Epoch 2: val_loss improved from 0.00192 to 0.00096, saving model to best_lstm_cfs.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0212 - mae: 0.1572 - val_loss: 9.5594e-04 - val_mae: 0.0348 - learning_rate: 3.0000e-04
# Epoch 3/300
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0129 - mae: 0.1202
# Epoch 3: val_loss improved from 0.00096 to 0.00070, saving model to best_lstm_cfs.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0127 - mae: 0.1192 - val_loss: 6.9650e-04 - val_mae: 0.0296 - learning_rate: 3.0000e-04
# Epoch 4/300
# 86/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0097 - mae: 0.1031
# Epoch 4: val_loss improved from 0.00070 to 0.00061, saving model to best_lstm_cfs.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0093 - mae: 0.1005 - val_loss: 6.1477e-04 - val_mae: 0.0273 - learning_rate: 3.0000e-04
# Epoch 5/300
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0078 - mae: 0.0929
# Epoch 5: val_loss did not improve from 0.00061
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0076 - mae: 0.0910 - val_loss: 7.1570e-04 - val_mae: 0.0289 - learning_rate: 3.0000e-04
# Epoch 6/300
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0085 - mae: 0.0957
# Epoch 6: val_loss did not improve from 0.00061
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0082 - mae: 0.0939 - val_loss: 7.6213e-04 - val_mae: 0.0294 - learning_rate: 3.0000e-04
# Epoch 7/300
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0085 - mae: 0.0971
# Epoch 7: val_loss did not improve from 0.00061
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0082 - mae: 0.0950 - val_loss: 7.2505e-04 - val_mae: 0.0285 - learning_rate: 3.0000e-04
# Epoch 8/300
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0085 - mae: 0.0985
# Epoch 8: val_loss did not improve from 0.00061
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0082 - mae: 0.0965 - val_loss: 6.9911e-04 - val_mae: 0.0283 - learning_rate: 3.0000e-04
# Epoch 9/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0086 - mae: 0.0994
# Epoch 9: val_loss did not improve from 0.00061
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0084 - mae: 0.0982 - val_loss: 6.4612e-04 - val_mae: 0.0270 - learning_rate: 3.0000e-04
# Epoch 10/300
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0083 - mae: 0.0978
# Epoch 10: val_loss did not improve from 0.00061
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0082 - mae: 0.0971 - val_loss: 6.9635e-04 - val_mae: 0.0288 - learning_rate: 3.0000e-04
# Epoch 11/300
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0089 - mae: 0.1020
# Epoch 11: val_loss did not improve from 0.00061
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0088 - mae: 0.1010 - val_loss: 6.6755e-04 - val_mae: 0.0279 - learning_rate: 3.0000e-04
# Epoch 12/300
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0088 - mae: 0.1033
# Epoch 12: val_loss did not improve from 0.00061
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0086 - mae: 0.1016 - val_loss: 6.5091e-04 - val_mae: 0.0281 - learning_rate: 3.0000e-04
# Epoch 13/300
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0085 - mae: 0.1010
# Epoch 13: val_loss did not improve from 0.00061
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0083 - mae: 0.0991 - val_loss: 6.8108e-04 - val_mae: 0.0289 - learning_rate: 3.0000e-04
# Epoch 14/300
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0085 - mae: 0.1010
# Epoch 14: val_loss did not improve from 0.00061
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0084 - mae: 0.1002 - val_loss: 6.2712e-04 - val_mae: 0.0270 - learning_rate: 3.0000e-04
# Epoch 15/300
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0090 - mae: 0.1036
# Epoch 15: val_loss did not improve from 0.00061
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0089 - mae: 0.1028 - val_loss: 6.2412e-04 - val_mae: 0.0275 - learning_rate: 3.0000e-04
# Epoch 16/300
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0081 - mae: 0.0972
# Epoch 16: val_loss improved from 0.00061 to 0.00059, saving model to best_lstm_cfs.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0079 - mae: 0.0956 - val_loss: 5.9458e-04 - val_mae: 0.0270 - learning_rate: 3.0000e-04
# Epoch 17/300
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0071 - mae: 0.0888
# Epoch 17: val_loss improved from 0.00059 to 0.00050, saving model to best_lstm_cfs.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0070 - mae: 0.0877 - val_loss: 5.0365e-04 - val_mae: 0.0227 - learning_rate: 3.0000e-04
# Epoch 18/300
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0088 - mae: 0.1021
# Epoch 18: val_loss did not improve from 0.00050
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0087 - mae: 0.1015 - val_loss: 5.6679e-04 - val_mae: 0.0258 - learning_rate: 3.0000e-04
# Epoch 19/300
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0081 - mae: 0.0984
# Epoch 19: val_loss improved from 0.00050 to 0.00050, saving model to best_lstm_cfs.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0080 - mae: 0.0976 - val_loss: 4.9674e-04 - val_mae: 0.0227 - learning_rate: 3.0000e-04
# Epoch 20/300
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0078 - mae: 0.0949
# Epoch 20: val_loss did not improve from 0.00050
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0076 - mae: 0.0936 - val_loss: 5.1410e-04 - val_mae: 0.0227 - learning_rate: 3.0000e-04
# Epoch 21/300
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0085 - mae: 0.1001
# Epoch 21: val_loss did not improve from 0.00050
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0083 - mae: 0.0994 - val_loss: 4.9944e-04 - val_mae: 0.0232 - learning_rate: 3.0000e-04
# Epoch 22/300
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0084 - mae: 0.1000
# Epoch 22: val_loss improved from 0.00050 to 0.00048, saving model to best_lstm_cfs.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0082 - mae: 0.0987 - val_loss: 4.8097e-04 - val_mae: 0.0225 - learning_rate: 3.0000e-04
# Epoch 23/300
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0082 - mae: 0.0993
# Epoch 23: val_loss did not improve from 0.00048
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0080 - mae: 0.0982 - val_loss: 4.8975e-04 - val_mae: 0.0224 - learning_rate: 3.0000e-04
# Epoch 24/300
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0082 - mae: 0.0995
# Epoch 24: val_loss improved from 0.00048 to 0.00047, saving model to best_lstm_cfs.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0081 - mae: 0.0989 - val_loss: 4.6865e-04 - val_mae: 0.0221 - learning_rate: 3.0000e-04
# Epoch 25/300
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0079 - mae: 0.0983
# Epoch 25: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0077 - mae: 0.0968 - val_loss: 4.7011e-04 - val_mae: 0.0223 - learning_rate: 3.0000e-04
# Epoch 26/300
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0083 - mae: 0.1002
# Epoch 26: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0081 - mae: 0.0986 - val_loss: 4.6890e-04 - val_mae: 0.0220 - learning_rate: 3.0000e-04
# Epoch 27/300
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0079 - mae: 0.0984
# Epoch 27: val_loss improved from 0.00047 to 0.00047, saving model to best_lstm_cfs.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0078 - mae: 0.0971 - val_loss: 4.6690e-04 - val_mae: 0.0221 - learning_rate: 3.0000e-04
# Epoch 28/300
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0076 - mae: 0.0944
# Epoch 28: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0076 - mae: 0.0942 - val_loss: 6.5418e-04 - val_mae: 0.0275 - learning_rate: 3.0000e-04
# Epoch 29/300
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0075 - mae: 0.0905
# Epoch 29: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0075 - mae: 0.0900 - val_loss: 5.6629e-04 - val_mae: 0.0247 - learning_rate: 3.0000e-04
# Epoch 30/300
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0076 - mae: 0.0950
# Epoch 30: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0074 - mae: 0.0936 - val_loss: 5.0035e-04 - val_mae: 0.0236 - learning_rate: 3.0000e-04
# Epoch 31/300
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0074 - mae: 0.0949
# Epoch 31: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0073 - mae: 0.0939 - val_loss: 4.9017e-04 - val_mae: 0.0238 - learning_rate: 3.0000e-04
# Epoch 32/300
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0072 - mae: 0.0946
# Epoch 32: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0071 - mae: 0.0935 - val_loss: 4.7494e-04 - val_mae: 0.0232 - learning_rate: 3.0000e-04
# Epoch 33/300
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0071 - mae: 0.0928
# Epoch 33: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0070 - mae: 0.0922 - val_loss: 4.8222e-04 - val_mae: 0.0237 - learning_rate: 3.0000e-04
# Epoch 34/300
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0072 - mae: 0.0934
# Epoch 34: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0071 - mae: 0.0928 - val_loss: 4.7711e-04 - val_mae: 0.0238 - learning_rate: 3.0000e-04
# Epoch 35/300
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0072 - mae: 0.0934
# Epoch 35: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0072 - mae: 0.0929 - val_loss: 4.6873e-04 - val_mae: 0.0235 - learning_rate: 3.0000e-04
# Epoch 36/300
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0068 - mae: 0.0903
# Epoch 36: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0067 - mae: 0.0895 - val_loss: 4.8114e-04 - val_mae: 0.0238 - learning_rate: 3.0000e-04
# Epoch 37/300
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0068 - mae: 0.0904
# Epoch 37: val_loss improved from 0.00047 to 0.00047, saving model to best_lstm_cfs.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0067 - mae: 0.0898 - val_loss: 4.6582e-04 - val_mae: 0.0237 - learning_rate: 3.0000e-04
# Epoch 38/300
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0075 - mae: 0.1001
# Epoch 38: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0074 - mae: 0.0999 - val_loss: 0.0011 - val_mae: 0.0391 - learning_rate: 1.5000e-04
# Epoch 39/300
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047 - mae: 0.0756
# Epoch 39: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0047 - mae: 0.0756 - val_loss: 9.1055e-04 - val_mae: 0.0349 - learning_rate: 1.5000e-04
# Epoch 40/300
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047 - mae: 0.0756
# Epoch 40: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0047 - mae: 0.0756 - val_loss: 8.2027e-04 - val_mae: 0.0326 - learning_rate: 1.5000e-04
# Epoch 41/300
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047 - mae: 0.0754
# Epoch 41: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0046 - mae: 0.0754 - val_loss: 8.3541e-04 - val_mae: 0.0331 - learning_rate: 1.5000e-04
# Epoch 42/300
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0046 - mae: 0.0747
# Epoch 42: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0046 - mae: 0.0749 - val_loss: 8.0774e-04 - val_mae: 0.0324 - learning_rate: 1.5000e-04
# Epoch 43/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0048 - mae: 0.0758
# Epoch 43: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0048 - mae: 0.0758 - val_loss: 8.4518e-04 - val_mae: 0.0335 - learning_rate: 1.5000e-04
# Epoch 44/300
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0045 - mae: 0.0742
# Epoch 44: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0045 - mae: 0.0743 - val_loss: 8.2811e-04 - val_mae: 0.0332 - learning_rate: 1.5000e-04
# Epoch 45/300
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0046 - mae: 0.0752
# Epoch 45: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0046 - mae: 0.0753 - val_loss: 8.5980e-04 - val_mae: 0.0339 - learning_rate: 1.5000e-04
# Epoch 46/300
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0045 - mae: 0.0738
# Epoch 46: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0045 - mae: 0.0739 - val_loss: 8.3828e-04 - val_mae: 0.0335 - learning_rate: 1.5000e-04
# Epoch 47/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - mae: 0.0728
# Epoch 47: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0044 - mae: 0.0728 - val_loss: 8.7064e-04 - val_mae: 0.0341 - learning_rate: 1.5000e-04
# Epoch 48/300
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - mae: 0.0716
# Epoch 48: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0044 - mae: 0.0720 - val_loss: 8.5315e-04 - val_mae: 0.0338 - learning_rate: 1.5000e-04
# Epoch 49/300
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - mae: 0.0719
# Epoch 49: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0044 - mae: 0.0719 - val_loss: 8.4370e-04 - val_mae: 0.0337 - learning_rate: 1.5000e-04
# Epoch 50/300
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0043 - mae: 0.0717
# Epoch 50: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0043 - mae: 0.0717 - val_loss: 8.5201e-04 - val_mae: 0.0339 - learning_rate: 1.5000e-04
# Epoch 51/300
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0045 - mae: 0.0727
# Epoch 51: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0045 - mae: 0.0727 - val_loss: 8.4629e-04 - val_mae: 0.0338 - learning_rate: 1.5000e-04
# Epoch 52/300
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0045 - mae: 0.0731
# Epoch 52: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0045 - mae: 0.0732 - val_loss: 9.4594e-04 - val_mae: 0.0359 - learning_rate: 1.5000e-04
# Epoch 53/300
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0043 - mae: 0.0728
# Epoch 53: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0043 - mae: 0.0728 - val_loss: 0.0016 - val_mae: 0.0476 - learning_rate: 7.5000e-05
# Epoch 54/300
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0037 - mae: 0.0649
# Epoch 54: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0037 - mae: 0.0655 - val_loss: 0.0016 - val_mae: 0.0467 - learning_rate: 7.5000e-05
# Epoch 55/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035 - mae: 0.0651
# Epoch 55: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0036 - mae: 0.0654 - val_loss: 0.0016 - val_mae: 0.0466 - learning_rate: 7.5000e-05
# Epoch 56/300
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0035 - mae: 0.0646
# Epoch 56: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0036 - mae: 0.0650 - val_loss: 0.0015 - val_mae: 0.0460 - learning_rate: 7.5000e-05
# Epoch 57/300
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035 - mae: 0.0635
# Epoch 57: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0035 - mae: 0.0638 - val_loss: 0.0015 - val_mae: 0.0453 - learning_rate: 7.5000e-05
# Epoch 58/300
# 86/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0036 - mae: 0.0646
# Epoch 58: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0037 - mae: 0.0652 - val_loss: 0.0014 - val_mae: 0.0449 - learning_rate: 7.5000e-05
# Epoch 59/300
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035 - mae: 0.0645
# Epoch 59: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0036 - mae: 0.0647 - val_loss: 0.0015 - val_mae: 0.0452 - learning_rate: 7.5000e-05
# Epoch 60/300
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035 - mae: 0.0644
# Epoch 60: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0035 - mae: 0.0647 - val_loss: 0.0014 - val_mae: 0.0445 - learning_rate: 7.5000e-05
# Epoch 61/300
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035 - mae: 0.0643
# Epoch 61: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0035 - mae: 0.0645 - val_loss: 0.0015 - val_mae: 0.0450 - learning_rate: 7.5000e-05
# Epoch 62/300
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0034 - mae: 0.0632
# Epoch 62: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0034 - mae: 0.0637 - val_loss: 0.0014 - val_mae: 0.0448 - learning_rate: 7.5000e-05
# Epoch 63/300
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035 - mae: 0.0640
# Epoch 63: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0035 - mae: 0.0642 - val_loss: 0.0014 - val_mae: 0.0440 - learning_rate: 7.5000e-05
# Epoch 64/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033 - mae: 0.0626
# Epoch 64: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0034 - mae: 0.0629 - val_loss: 0.0014 - val_mae: 0.0446 - learning_rate: 7.5000e-05
# Epoch 65/300
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0034 - mae: 0.0636
# Epoch 65: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0035 - mae: 0.0640 - val_loss: 0.0014 - val_mae: 0.0435 - learning_rate: 7.5000e-05
# Epoch 66/300
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035 - mae: 0.0634
# Epoch 66: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0035 - mae: 0.0637 - val_loss: 0.0014 - val_mae: 0.0443 - learning_rate: 7.5000e-05
# Epoch 67/300
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0034 - mae: 0.0634
# Epoch 67: val_loss did not improve from 0.00047
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0034 - mae: 0.0635 - val_loss: 0.0014 - val_mae: 0.0439 - learning_rate: 7.5000e-05

# %%
# import tensorflow as tf

# # GPU 사용 가능한지 확인
# gpus = tf.config.list_physical_devices('GPU')
# if gpus:
#     print(f"사용 가능한 GPU: {gpus}")
# else:
#     print("GPU를 찾을 수 없습니다. CPU를 사용합니다.")

# %%
# !pip uninstall tensorflow
# !pip install tensorflow

# %%
# !pip install tensorflow-gpu==2.6.0

# %%
# !nvcc --version  # CUDA Toolkit 버전 확인

# %%
# 테스트 데이터셋에서 예측 수행
y_pred_scaled = lstm.predict(test_ds)  # (samples, n_horizon) 형태

# y_pred를 (samples, 1)로 변환
y_pred = y_pred_scaled.reshape(-1, 1)  # 2차원으로 변환

# y_pred의 스케일 복원
y_pred = mm_Y.inverse_transform(y_pred)

# y_true를 TensorFlow Dataset에서 추출 및 스케일 복원
y_true_scaled = np.concatenate([y for x, y in test_ds], axis=0)  # (samples, n_horizon)
y_true = y_true_scaled.reshape(-1, 1)  # 2차원으로 변환
y_true = mm_Y.inverse_transform(y_true)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# MAE (Mean Absolute Error)
mae = mean_absolute_error(y_true, y_pred)

# RMSE (Root Mean Squared Error)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))

# MAPE (Mean Absolute Percentage Error)
mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# 성능 결과 출력
print(f"MAE: {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"MAPE: {mape:.2f}%")
# Out:
# MAE: 1.06
# RMSE: 1.37
# MAPE: 8.90%

# %%
import matplotlib.pyplot as plt

# 샘플 수 선택 (테스트 데이터 일부만 시각화)

plt.figure(figsize=(12, 6))

plt.plot(y_true, label="True Values", marker='o')
plt.plot(y_pred, label="Predictions", marker='x')

plt.title("True vs Predicted Cooling Power")
plt.xlabel("Time Steps")
plt.ylabel("Cooling Power")
plt.legend()
plt.grid()
plt.show()

# %%
class PositionEmbedding(tf.keras.layers.Layer):
    def __init__(self, max_len, embed_dim):
        super().__init__()
        self.pos_embedding = tf.keras.layers.Embedding(input_dim=max_len, output_dim=embed_dim)

    def call(self, inputs):
        positions = tf.range(start=0, limit=tf.shape(inputs)[1], delta=1)
        positions = self.pos_embedding(positions)
        return inputs + positions

# %%
def transformer_model(n_steps, n_horizon, n_features, lr):
    """Creates an optimized Transformer model for time series forecasting."""

    # Clear any previous session
    tf.keras.backend.clear_session()

    # Input Layer
    inputs = tf.keras.layers.Input(shape=(n_steps, n_features))

    # Position Embedding
    position_embedding = PositionEmbedding(max_len=n_steps, embed_dim=n_features)(inputs)

    # Transformer Encoder
    transformer = tf.keras.layers.MultiHeadAttention(num_heads=4, key_dim=64)(position_embedding, position_embedding)
    transformer = tf.keras.layers.LayerNormalization(epsilon=1e-6)(transformer)
    transformer = tf.keras.layers.Dropout(0.1)(transformer)

    # Feed-Forward Network
    ff = tf.keras.layers.Dense(128, activation="relu")(transformer)
    ff = tf.keras.layers.Dropout(0.1)(ff)
    ff = tf.keras.layers.Dense(64, activation="relu")(ff)
    ff = tf.keras.layers.LayerNormalization(epsilon=1e-6)(ff)

    # Global Average Pooling
    pooled = tf.keras.layers.GlobalAveragePooling1D()(ff)

    # Output Layer
    outputs = tf.keras.layers.Dense(n_horizon)(pooled)

    # Build Model
    model = tf.keras.models.Model(inputs=inputs, outputs=outputs, name="transformer")

    # Custom Learning Rate
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate=lr,
        decay_steps=1000,
        decay_rate=0.96,
        staircase=True
    )

    # Compile Model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
                  loss="mse",
                  metrics=["mae"])

    return model

# %%
# EarlyStopping 콜백
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# %%
model_checkpoint = ModelCheckpoint(
    filepath='best_transformer_cfs.keras',  # 저장 경로
    monitor='val_loss',       # 모니터링할 값
    save_best_only=True,      # Best 모델만 저장
    verbose=1
)

# %%
# LSTM 모델 생성
transformer = transformer_model(n_steps=12, n_horizon=1, n_features=train_X_scaled.shape[1], lr=3e-4)

# EarlyStopping 콜백
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# Learning Rate Decay 콜백
lr_decay = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=15, min_lr=1e-5)

# 모델 학습
history_transformer = transformer.fit(
    train_ds,
    validation_data=val_ds,
    epochs=100,
      callbacks=[early_stopping,model_checkpoint]  # 콜백 추가
)
# Out:
# Epoch 1/100
#      93/Unknown 3s 5ms/step - loss: 0.2172 - mae: 0.2791
# c:\Users\Yoon\.conda\envs\gpt\Lib\site-packages\keras\src\trainers\epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 1: val_loss improved from inf to 0.00440, saving model to best_transformer_cfs.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.2126 - mae: 0.2753 - val_loss: 0.0044 - val_mae: 0.0585
# Epoch 2/100
# 86/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0188 - mae: 0.1096
# Epoch 2: val_loss improved from 0.00440 to 0.00322, saving model to best_transformer_cfs.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0185 - mae: 0.1087 - val_loss: 0.0032 - val_mae: 0.0490
# Epoch 3/100
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0134 - mae: 0.0917
# Epoch 3: val_loss did not improve from 0.00322
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0134 - mae: 0.0916 - val_loss: 0.0039 - val_mae: 0.0539
# Epoch 4/100
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0128 - mae: 0.0882
# Epoch 4: val_loss did not improve from 0.00322
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0128 - mae: 0.0881 - val_loss: 0.0066 - val_mae: 0.0722
# Epoch 5/100
# 85/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0121 - mae: 0.0876
# Epoch 5: val_loss improved from 0.00322 to 0.00155, saving model to best_transformer_cfs.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0119 - mae: 0.0869 - val_loss: 0.0015 - val_mae: 0.0309
# Epoch 6/100
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0095 - mae: 0.0757
# Epoch 6: val_loss did not improve from 0.00155
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0095 - mae: 0.0756 - val_loss: 0.0029 - val_mae: 0.0450
# Epoch 7/100
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0097 - mae: 0.0767
# Epoch 7: val_loss did not improve from 0.00155
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0097 - mae: 0.0765 - val_loss: 0.0023 - val_mae: 0.0398
# Epoch 8/100
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0081 - mae: 0.0682
# Epoch 8: val_loss did not improve from 0.00155
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0081 - mae: 0.0681 - val_loss: 0.0026 - val_mae: 0.0435
# Epoch 9/100
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0081 - mae: 0.0686
# Epoch 9: val_loss did not improve from 0.00155
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0080 - mae: 0.0684 - val_loss: 0.0028 - val_mae: 0.0446
# Epoch 10/100
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mae: 0.0635
# Epoch 10: val_loss did not improve from 0.00155
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0070 - mae: 0.0634 - val_loss: 0.0020 - val_mae: 0.0361
# Epoch 11/100
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mae: 0.0623
# Epoch 11: val_loss did not improve from 0.00155
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0068 - mae: 0.0621 - val_loss: 0.0022 - val_mae: 0.0376
# Epoch 12/100
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0070 - mae: 0.0644
# Epoch 12: val_loss did not improve from 0.00155
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0070 - mae: 0.0642 - val_loss: 0.0020 - val_mae: 0.0347
# Epoch 13/100
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0064 - mae: 0.0592
# Epoch 13: val_loss did not improve from 0.00155
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0064 - mae: 0.0591 - val_loss: 0.0016 - val_mae: 0.0314
# Epoch 14/100
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0065 - mae: 0.0590
# Epoch 14: val_loss did not improve from 0.00155
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0064 - mae: 0.0588 - val_loss: 0.0020 - val_mae: 0.0343
# Epoch 15/100
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0065 - mae: 0.0617
# Epoch 15: val_loss did not improve from 0.00155
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0064 - mae: 0.0614 - val_loss: 0.0017 - val_mae: 0.0320
# Epoch 16/100
# 86/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0062 - mae: 0.0596
# Epoch 16: val_loss improved from 0.00155 to 0.00114, saving model to best_transformer_cfs.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0062 - mae: 0.0596 - val_loss: 0.0011 - val_mae: 0.0251
# Epoch 17/100
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0073 - mae: 0.0648
# Epoch 17: val_loss did not improve from 0.00114
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0073 - mae: 0.0643 - val_loss: 0.0013 - val_mae: 0.0264
# Epoch 18/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0063 - mae: 0.0605
# Epoch 18: val_loss did not improve from 0.00114
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0063 - mae: 0.0604 - val_loss: 0.0014 - val_mae: 0.0290
# Epoch 19/100
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0057 - mae: 0.0575
# Epoch 19: val_loss did not improve from 0.00114
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0057 - mae: 0.0574 - val_loss: 0.0014 - val_mae: 0.0281
# Epoch 20/100
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0054 - mae: 0.0567
# Epoch 20: val_loss did not improve from 0.00114
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0054 - mae: 0.0566 - val_loss: 0.0012 - val_mae: 0.0262
# Epoch 21/100
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0058 - mae: 0.0586
# Epoch 21: val_loss did not improve from 0.00114
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0058 - mae: 0.0583 - val_loss: 0.0014 - val_mae: 0.0281
# Epoch 22/100
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0057 - mae: 0.0559
# Epoch 22: val_loss did not improve from 0.00114
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0056 - mae: 0.0558 - val_loss: 0.0013 - val_mae: 0.0267
# Epoch 23/100
# 86/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0058 - mae: 0.0577
# Epoch 23: val_loss did not improve from 0.00114
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0057 - mae: 0.0571 - val_loss: 0.0013 - val_mae: 0.0272
# Epoch 24/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0050 - mae: 0.0515
# Epoch 24: val_loss did not improve from 0.00114
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0050 - mae: 0.0515 - val_loss: 0.0014 - val_mae: 0.0279
# Epoch 25/100
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0057 - mae: 0.0563
# Epoch 25: val_loss did not improve from 0.00114
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0057 - mae: 0.0561 - val_loss: 0.0015 - val_mae: 0.0292
# Epoch 26/100
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0047 - mae: 0.0493
# Epoch 26: val_loss did not improve from 0.00114
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0047 - mae: 0.0494 - val_loss: 0.0014 - val_mae: 0.0282
# Epoch 27/100
# 84/95 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0050 - mae: 0.0525
# Epoch 27: val_loss did not improve from 0.00114
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0049 - mae: 0.0522 - val_loss: 0.0014 - val_mae: 0.0279
# Epoch 28/100
# 84/95 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0050 - mae: 0.0526
# Epoch 28: val_loss did not improve from 0.00114
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0049 - mae: 0.0523 - val_loss: 0.0014 - val_mae: 0.0278
# Epoch 29/100
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0052 - mae: 0.0518
# Epoch 29: val_loss did not improve from 0.00114
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0052 - mae: 0.0518 - val_loss: 0.0012 - val_mae: 0.0253
# Epoch 30/100
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0053 - mae: 0.0542
# Epoch 30: val_loss did not improve from 0.00114
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0053 - mae: 0.0540 - val_loss: 0.0013 - val_mae: 0.0273
# Epoch 31/100
# 85/95 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0051 - mae: 0.0509
# Epoch 31: val_loss did not improve from 0.00114
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0050 - mae: 0.0507 - val_loss: 0.0012 - val_mae: 0.0257
# Epoch 32/100
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0052 - mae: 0.0533
# Epoch 32: val_loss did not improve from 0.00114
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0052 - mae: 0.0532 - val_loss: 0.0013 - val_mae: 0.0271
# Epoch 33/100
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0046 - mae: 0.0475
# Epoch 33: val_loss did not improve from 0.00114
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0046 - mae: 0.0474 - val_loss: 0.0014 - val_mae: 0.0277
# Epoch 34/100
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0045 - mae: 0.0470
# Epoch 34: val_loss did not improve from 0.00114
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0045 - mae: 0.0470 - val_loss: 0.0014 - val_mae: 0.0286
# Epoch 35/100
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0043 - mae: 0.0475
# Epoch 35: val_loss did not improve from 0.00114
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0043 - mae: 0.0473 - val_loss: 0.0012 - val_mae: 0.0265
# Epoch 36/100
# 85/95 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0047 - mae: 0.0486
# Epoch 36: val_loss did not improve from 0.00114
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0046 - mae: 0.0484 - val_loss: 0.0013 - val_mae: 0.0272
# Epoch 37/100
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0042 - mae: 0.0471
# Epoch 37: val_loss did not improve from 0.00114
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0042 - mae: 0.0468 - val_loss: 0.0012 - val_mae: 0.0259
# Epoch 38/100
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0040 - mae: 0.0451
# Epoch 38: val_loss did not improve from 0.00114
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0040 - mae: 0.0450 - val_loss: 0.0011 - val_mae: 0.0263
# Epoch 39/100
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0044 - mae: 0.0476
# Epoch 39: val_loss improved from 0.00114 to 0.00102, saving model to best_transformer_cfs.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0044 - mae: 0.0475 - val_loss: 0.0010 - val_mae: 0.0243
# Epoch 40/100
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0044 - mae: 0.0483
# Epoch 40: val_loss improved from 0.00102 to 0.00102, saving model to best_transformer_cfs.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0044 - mae: 0.0480 - val_loss: 0.0010 - val_mae: 0.0251
# Epoch 41/100
# 85/95 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0041 - mae: 0.0452
# Epoch 41: val_loss did not improve from 0.00102
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0041 - mae: 0.0449 - val_loss: 0.0012 - val_mae: 0.0261
# Epoch 42/100
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0037 - mae: 0.0438
# Epoch 42: val_loss did not improve from 0.00102
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0037 - mae: 0.0438 - val_loss: 0.0012 - val_mae: 0.0257
# Epoch 43/100
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0039 - mae: 0.0447
# Epoch 43: val_loss did not improve from 0.00102
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0039 - mae: 0.0447 - val_loss: 0.0012 - val_mae: 0.0259
# Epoch 44/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0041 - mae: 0.0436
# Epoch 44: val_loss did not improve from 0.00102
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0041 - mae: 0.0436 - val_loss: 0.0012 - val_mae: 0.0260
# Epoch 45/100
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0040 - mae: 0.0434
# Epoch 45: val_loss did not improve from 0.00102
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0040 - mae: 0.0434 - val_loss: 0.0012 - val_mae: 0.0254
# Epoch 46/100
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0041 - mae: 0.0453
# Epoch 46: val_loss did not improve from 0.00102
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0041 - mae: 0.0451 - val_loss: 0.0011 - val_mae: 0.0255
# Epoch 47/100
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0039 - mae: 0.0442
# Epoch 47: val_loss did not improve from 0.00102
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0039 - mae: 0.0441 - val_loss: 0.0013 - val_mae: 0.0268
# Epoch 48/100
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - mae: 0.0431
# Epoch 48: val_loss did not improve from 0.00102
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0039 - mae: 0.0430 - val_loss: 0.0013 - val_mae: 0.0262
# Epoch 49/100
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0042 - mae: 0.0446
# Epoch 49: val_loss did not improve from 0.00102
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0041 - mae: 0.0444 - val_loss: 0.0011 - val_mae: 0.0251
# Epoch 50/100
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0039 - mae: 0.0441
# Epoch 50: val_loss did not improve from 0.00102
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0039 - mae: 0.0440 - val_loss: 0.0011 - val_mae: 0.0256
# Epoch 51/100
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0039 - mae: 0.0427
# Epoch 51: val_loss did not improve from 0.00102
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0039 - mae: 0.0426 - val_loss: 0.0012 - val_mae: 0.0256
# Epoch 52/100
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0041 - mae: 0.0444
# Epoch 52: val_loss did not improve from 0.00102
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0041 - mae: 0.0441 - val_loss: 0.0011 - val_mae: 0.0251
# Epoch 53/100
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0039 - mae: 0.0443
# Epoch 53: val_loss improved from 0.00102 to 0.00096, saving model to best_transformer_cfs.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0039 - mae: 0.0441 - val_loss: 9.6036e-04 - val_mae: 0.0238
# Epoch 54/100
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0037 - mae: 0.0423
# Epoch 54: val_loss did not improve from 0.00096
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0037 - mae: 0.0423 - val_loss: 0.0012 - val_mae: 0.0262
# Epoch 55/100
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0041 - mae: 0.0449
# Epoch 55: val_loss did not improve from 0.00096
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0041 - mae: 0.0448 - val_loss: 0.0011 - val_mae: 0.0253
# Epoch 56/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0036 - mae: 0.0429
# Epoch 56: val_loss did not improve from 0.00096
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0036 - mae: 0.0428 - val_loss: 0.0012 - val_mae: 0.0268
# Epoch 57/100
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0038 - mae: 0.0423
# Epoch 57: val_loss did not improve from 0.00096
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0038 - mae: 0.0422 - val_loss: 0.0015 - val_mae: 0.0287
# Epoch 58/100
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0035 - mae: 0.0403
# Epoch 58: val_loss did not improve from 0.00096
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0035 - mae: 0.0403 - val_loss: 0.0013 - val_mae: 0.0271
# Epoch 59/100
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0040 - mae: 0.0428
# Epoch 59: val_loss did not improve from 0.00096
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0039 - mae: 0.0427 - val_loss: 0.0014 - val_mae: 0.0276
# Epoch 60/100
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0034 - mae: 0.0407
# Epoch 60: val_loss did not improve from 0.00096
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0034 - mae: 0.0406 - val_loss: 0.0012 - val_mae: 0.0263
# Epoch 61/100
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0037 - mae: 0.0422
# Epoch 61: val_loss did not improve from 0.00096
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0037 - mae: 0.0421 - val_loss: 0.0011 - val_mae: 0.0248
# Epoch 62/100
# 86/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0041 - mae: 0.0451
# Epoch 62: val_loss did not improve from 0.00096
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0040 - mae: 0.0448 - val_loss: 0.0011 - val_mae: 0.0240
# Epoch 63/100
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0035 - mae: 0.0426
# Epoch 63: val_loss improved from 0.00096 to 0.00088, saving model to best_transformer_cfs.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0035 - mae: 0.0425 - val_loss: 8.7955e-04 - val_mae: 0.0226
# Epoch 64/100
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0037 - mae: 0.0413
# Epoch 64: val_loss did not improve from 0.00088
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0037 - mae: 0.0413 - val_loss: 0.0012 - val_mae: 0.0260
# Epoch 65/100
# 85/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0036 - mae: 0.0407
# Epoch 65: val_loss did not improve from 0.00088
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0036 - mae: 0.0407 - val_loss: 0.0014 - val_mae: 0.0271
# Epoch 66/100
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0035 - mae: 0.0407
# Epoch 66: val_loss did not improve from 0.00088
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0035 - mae: 0.0407 - val_loss: 9.2623e-04 - val_mae: 0.0227
# Epoch 67/100
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0035 - mae: 0.0402
# Epoch 67: val_loss did not improve from 0.00088
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0035 - mae: 0.0402 - val_loss: 9.9598e-04 - val_mae: 0.0238
# Epoch 68/100
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0034 - mae: 0.0408
# Epoch 68: val_loss did not improve from 0.00088
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0034 - mae: 0.0408 - val_loss: 9.4364e-04 - val_mae: 0.0230
# Epoch 69/100
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0038 - mae: 0.0420
# Epoch 69: val_loss did not improve from 0.00088
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0038 - mae: 0.0419 - val_loss: 9.9228e-04 - val_mae: 0.0234
# Epoch 70/100
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0033 - mae: 0.0404
# Epoch 70: val_loss did not improve from 0.00088
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0033 - mae: 0.0404 - val_loss: 9.0847e-04 - val_mae: 0.0226
# Epoch 71/100
# 85/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0037 - mae: 0.0423
# Epoch 71: val_loss did not improve from 0.00088
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0037 - mae: 0.0421 - val_loss: 8.9758e-04 - val_mae: 0.0220
# Epoch 72/100
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0037 - mae: 0.0425
# Epoch 72: val_loss did not improve from 0.00088
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0037 - mae: 0.0424 - val_loss: 9.9078e-04 - val_mae: 0.0235
# Epoch 73/100
# 86/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0034 - mae: 0.0413
# Epoch 73: val_loss did not improve from 0.00088
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0034 - mae: 0.0413 - val_loss: 8.8299e-04 - val_mae: 0.0219
# Epoch 74/100
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0037 - mae: 0.0417
# Epoch 74: val_loss improved from 0.00088 to 0.00085, saving model to best_transformer_cfs.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0037 - mae: 0.0416 - val_loss: 8.5165e-04 - val_mae: 0.0220
# Epoch 75/100
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0038 - mae: 0.0430
# Epoch 75: val_loss improved from 0.00085 to 0.00082, saving model to best_transformer_cfs.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0038 - mae: 0.0429 - val_loss: 8.1591e-04 - val_mae: 0.0213
# Epoch 76/100
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0039 - mae: 0.0443
# Epoch 76: val_loss did not improve from 0.00082
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0039 - mae: 0.0442 - val_loss: 8.1829e-04 - val_mae: 0.0216
# Epoch 77/100
# 85/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0043 - mae: 0.0459
# Epoch 77: val_loss did not improve from 0.00082
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0043 - mae: 0.0454 - val_loss: 8.3687e-04 - val_mae: 0.0221
# Epoch 78/100
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0040 - mae: 0.0453
# Epoch 78: val_loss did not improve from 0.00082
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0040 - mae: 0.0453 - val_loss: 8.6490e-04 - val_mae: 0.0224
# Epoch 79/100
# 86/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0038 - mae: 0.0438
# Epoch 79: val_loss did not improve from 0.00082
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0038 - mae: 0.0437 - val_loss: 8.9409e-04 - val_mae: 0.0232
# Epoch 80/100
# 85/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0040 - mae: 0.0451
# Epoch 80: val_loss did not improve from 0.00082
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0040 - mae: 0.0449 - val_loss: 8.8824e-04 - val_mae: 0.0228
# Epoch 81/100
# 86/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0042 - mae: 0.0450
# Epoch 81: val_loss did not improve from 0.00082
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0042 - mae: 0.0449 - val_loss: 0.0010 - val_mae: 0.0252
# Epoch 82/100
# 86/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0043 - mae: 0.0483
# Epoch 82: val_loss did not improve from 0.00082
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0043 - mae: 0.0478 - val_loss: 0.0010 - val_mae: 0.0252
# Epoch 83/100
# 86/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0042 - mae: 0.0468
# Epoch 83: val_loss did not improve from 0.00082
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0041 - mae: 0.0465 - val_loss: 9.8189e-04 - val_mae: 0.0243
# Epoch 84/100
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0048 - mae: 0.0491
# Epoch 84: val_loss did not improve from 0.00082
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0048 - mae: 0.0489 - val_loss: 0.0010 - val_mae: 0.0249
# Epoch 85/100
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0051 - mae: 0.0514
# Epoch 85: val_loss did not improve from 0.00082
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0050 - mae: 0.0510 - val_loss: 0.0010 - val_mae: 0.0251
# Epoch 86/100
# 86/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0047 - mae: 0.0518
# Epoch 86: val_loss did not improve from 0.00082
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0047 - mae: 0.0516 - val_loss: 8.3787e-04 - val_mae: 0.0213
# Epoch 87/100
# 85/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0059 - mae: 0.0558
# Epoch 87: val_loss did not improve from 0.00082
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0058 - mae: 0.0554 - val_loss: 8.1654e-04 - val_mae: 0.0213
# Epoch 88/100
# 84/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0056 - mae: 0.0561
# Epoch 88: val_loss improved from 0.00082 to 0.00065, saving model to best_transformer_cfs.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0055 - mae: 0.0555 - val_loss: 6.4829e-04 - val_mae: 0.0189
# Epoch 89/100
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0059 - mae: 0.0573
# Epoch 89: val_loss improved from 0.00065 to 0.00064, saving model to best_transformer_cfs.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0058 - mae: 0.0569 - val_loss: 6.3611e-04 - val_mae: 0.0191
# Epoch 90/100
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0062 - mae: 0.0579
# Epoch 90: val_loss did not improve from 0.00064
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0062 - mae: 0.0578 - val_loss: 7.1030e-04 - val_mae: 0.0208
# Epoch 91/100
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0063 - mae: 0.0573
# Epoch 91: val_loss did not improve from 0.00064
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0063 - mae: 0.0570 - val_loss: 7.6744e-04 - val_mae: 0.0218
# Epoch 92/100
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0064 - mae: 0.0596
# Epoch 92: val_loss did not improve from 0.00064
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0064 - mae: 0.0595 - val_loss: 9.2963e-04 - val_mae: 0.0246
# Epoch 93/100
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0061 - mae: 0.0565
# Epoch 93: val_loss did not improve from 0.00064
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0061 - mae: 0.0564 - val_loss: 0.0010 - val_mae: 0.0266
# Epoch 94/100
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0064 - mae: 0.0572
# Epoch 94: val_loss did not improve from 0.00064
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0063 - mae: 0.0571 - val_loss: 0.0012 - val_mae: 0.0292
# Epoch 95/100
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0065 - mae: 0.0567
# Epoch 95: val_loss did not improve from 0.00064
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0064 - mae: 0.0566 - val_loss: 0.0014 - val_mae: 0.0319
# Epoch 96/100
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0064 - mae: 0.0559
# Epoch 96: val_loss did not improve from 0.00064
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0064 - mae: 0.0557 - val_loss: 0.0015 - val_mae: 0.0329
# Epoch 97/100
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0065 - mae: 0.0562
# Epoch 97: val_loss did not improve from 0.00064
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0064 - mae: 0.0560 - val_loss: 0.0016 - val_mae: 0.0350
# Epoch 98/100
# 85/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0061 - mae: 0.0544
# Epoch 98: val_loss did not improve from 0.00064
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0060 - mae: 0.0542 - val_loss: 0.0015 - val_mae: 0.0329
# Epoch 99/100
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0064 - mae: 0.0564
# Epoch 99: val_loss did not improve from 0.00064
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0064 - mae: 0.0562 - val_loss: 0.0014 - val_mae: 0.0316
# Epoch 100/100
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0063 - mae: 0.0553
# Epoch 100: val_loss did not improve from 0.00064
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0063 - mae: 0.0551 - val_loss: 0.0013 - val_mae: 0.0300

# %%
# 테스트 데이터셋에서 예측 수행
y_pred_scaled = transformer.predict(test_ds)  # (samples, n_horizon) 형태

# y_pred를 (samples, 1)로 변환
y_pred = y_pred_scaled.reshape(-1, 1)  # 2차원으로 변환

# y_pred의 스케일 복원
y_pred = mm_Y.inverse_transform(y_pred)

# y_true를 TensorFlow Dataset에서 추출 및 스케일 복원
y_true_scaled = np.concatenate([y for x, y in test_ds], axis=0)  # (samples, n_horizon)
y_true = y_true_scaled.reshape(-1, 1)  # 2차원으로 변환
y_true = mm_Y.inverse_transform(y_true)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# 성능 평가
from sklearn.metrics import mean_absolute_error, mean_squared_error

# MAE (Mean Absolute Error)
mae = mean_absolute_error(y_true, y_pred)

# RMSE (Root Mean Squared Error)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))

# MAPE (Mean Absolute Percentage Error)
mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# 성능 결과 출력
print(f"Transformer Results")
print(f"MAE: {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"MAPE: {mape:.2f}%")
# Out:
# Transformer Results
# MAE: 0.70
# RMSE: 0.91
# MAPE: 5.66%

# %%
# 시각화
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

# 샘플 수 선택 (테스트 데이터 일부만 시각화)
plt.plot(y_true[:100], label="True Values", marker='o', linestyle='-', alpha=0.7)
plt.plot(y_pred[:100], label="Predictions", marker='x', linestyle='--', alpha=0.7)

plt.title("Transformer: True vs Predicted Cooling Power")
plt.xlabel("Time Steps")
plt.ylabel("Cooling Power")
plt.legend()
plt.grid()
plt.show()
