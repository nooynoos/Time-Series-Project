# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import tensorflow as tf
import random
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# %%
SEED = 12
np.random.seed(SEED)
tf.random.set_seed(SEED)
random.seed(SEED)

# %%
# import pandas as pd

# # 기존 데이터 경로
# data_path = r"C:\Users\Yoon\OneDrive\한양대학교\3-2\시계열\Assignment\Project\DB\Final_1h_No Missing.csv"

# # 새로 포함할 Feature 목록
# selected_features = ['inner_temperature', 'outside_temperature', 'wind_speed', 'timestamp', 'cooling_power']

# # 데이터 로드
# df = pd.read_csv(data_path)

# # 선택된 Feature만 포함
# df_selected = df[selected_features]

# # 새로운 파일 저장 경로
# output_path = r"C:\Users\Yoon\OneDrive\한양대학교\3-2\시계열\Assignment\Project\DB\Selected_Features.csv"
# df_selected.to_csv(output_path, index=False)

# output_path

# %%
data_path = r"C:\Users\Yoon\OneDrive\한양대학교\3-2\시계열\Assignment\Project\DB\Clipped_all_features.csv"

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# 데이터 경로 설정
data_path = r"C:\Users\Yoon\OneDrive\한양대학교\3-2\시계열\Assignment\Project\DB\Clipped_all_features.csv"

def load_data(path=data_path):
    """Loads the dataset, drops 'timestamp', and splits into X (features) and Y (target)."""
    df = pd.read_csv(path)
    df = df.drop(columns=['timestamp'])  # 'timestamp' 제거
    X = df.drop(columns=['cooling_power'])  # 입력 변수
    Y = df[['cooling_power']]  # 타겟 변수
    return X, Y



def split_data(X, Y, train_fraq, test_len=108):
    """Splits input X and target Y into train, val, and test sets."""
    if test_len > len(X):
        raise ValueError("test_len cannot be greater than the total number of samples.")
    
    test_slice = len(X) - test_len

    X_test, Y_test = X[test_slice:], Y[test_slice:]
    X_train_val, Y_train_val = X[:test_slice], Y[:test_slice]

    train_size = int(len(X_train_val) * train_fraq)

    X_train, Y_train = X_train_val[:train_size], Y_train_val[:train_size]
    X_val, Y_val = X_train_val[train_size:], Y_train_val[train_size:]

    return (X_train, Y_train), (X_val, Y_val), (X_test, Y_test)


def min_max_scale(train_X, train_Y, val_X, val_Y, test_X, test_Y):
    """Applies MinMax Scaling using only the Train data for fitting."""
    mm_X = MinMaxScaler()
    mm_Y = MinMaxScaler()

    # Fit on Train data only
    train_X_scaled = mm_X.fit_transform(train_X)
    train_Y_scaled = mm_Y.fit_transform(train_Y)

    # Transform Validation and Test data
    val_X_scaled = mm_X.transform(val_X)
    val_Y_scaled = mm_Y.transform(val_Y)
    test_X_scaled = mm_X.transform(test_X)
    test_Y_scaled = mm_Y.transform(test_Y)

    return (train_X_scaled, train_Y_scaled), (val_X_scaled, val_Y_scaled), (test_X_scaled, test_Y_scaled), mm_X, mm_Y


def window_dataset(X, Y, n_steps, n_horizon, batch_size, shuffle_buffer, for_training=True):
    """
    Creates a windowed TensorFlow dataset.
    
    Parameters:
    - X: Input features
    - Y: Target values
    - n_steps: Number of timesteps in input
    - n_horizon: Prediction horizon
    - batch_size: Batch size for the dataset
    - shuffle_buffer: Buffer size for shuffling (applies only for training)
    - for_training: If True, applies shuffling for training data
    
    Returns:
    - A TensorFlow dataset object.
    """
    # Sliding window generation
    ds_X = tf.data.Dataset.from_tensor_slices(X)
    ds_Y = tf.data.Dataset.from_tensor_slices(Y)

    # Apply window
    ds_X = ds_X.window(n_steps, shift=n_horizon, drop_remainder=True).flat_map(lambda x: x.batch(n_steps))
    ds_Y = ds_Y.window(n_horizon, shift=n_horizon, drop_remainder=True).flat_map(lambda x: x.batch(n_horizon))

    # Combine inputs and targets
    ds = tf.data.Dataset.zip((ds_X, ds_Y))

    # Apply shuffle only for training data
    if for_training:
        ds = ds.shuffle(shuffle_buffer)

    # Batch and prefetch
    ds = ds.batch(batch_size).prefetch(1)
    return ds

# %%
def lstm_model(n_steps, n_horizon, n_features, lr):
    """Creates an LSTM model for predicting a single target variable."""

    # Clear any previous session
    tf.keras.backend.clear_session()

    # Build the model
    model = tf.keras.models.Sequential([
        # First LSTM Layer
        tf.keras.layers.LSTM(72, activation='relu', input_shape=(n_steps, n_features), return_sequences=True),
        
        # Second LSTM Layer
        tf.keras.layers.LSTM(48, activation='relu', return_sequences=False),
        
        # Dense Layers for Prediction
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.3),  # Dropout for regularization
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.3),  # Additional Dropout Layer
        
        # Output Layer (single value for n_horizon=1)
        tf.keras.layers.Dense(n_horizon)  # n_horizon=1 for single step prediction
    ], name='lstm')

    # Define loss and optimizer
    loss = tf.keras.losses.Huber()
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)

    # Compile the model
    model.compile(loss=loss, optimizer=optimizer, metrics=['mae'])

    return model

# %%
X, Y = load_data()

# 데이터 분리
(train_X, train_Y), (val_X, val_Y), (test_X, test_Y) = split_data(X, Y, train_fraq=0.82, test_len=651)

# MinMax Scaling
(train_X_scaled, train_Y_scaled), (val_X_scaled, val_Y_scaled), (test_X_scaled, test_Y_scaled), mm_X, mm_Y = min_max_scale(
    train_X, train_Y, val_X, val_Y, test_X, test_Y
)

# TensorFlow Dataset 생성
train_ds = window_dataset(train_X_scaled, train_Y_scaled, n_steps=12, n_horizon=1, batch_size=32, shuffle_buffer=100, for_training=True)
val_ds = window_dataset(val_X_scaled, val_Y_scaled, n_steps=12, n_horizon=1, batch_size=32, shuffle_buffer=0, for_training=False)
test_ds = window_dataset(test_X_scaled, test_Y_scaled, n_steps=12, n_horizon=1, batch_size=32, shuffle_buffer=0, for_training=False)

# %%
# 스케일링 확인
print("Original train_Y range:", train_Y.min(), train_Y.max())
print("Scaled train_Y range:", train_Y_scaled.min(), train_Y_scaled.max())

# 복원 확인
train_Y_restored = mm_Y.inverse_transform(train_Y_scaled)
print("Restored train_Y range:", train_Y_restored.min(), train_Y_restored.max())
# Out:
# Original train_Y range: cooling_power    0.958901
# dtype: float64 cooling_power    30.519911
# dtype: float64
# Scaled train_Y range: 0.0 0.9999999999999999
# Restored train_Y range: 0.958901250000002 30.519911249999996

# %%
print("Original train_X range:", train_X.min(), train_X.max())
print("Scaled train_X range:", train_X_scaled.min(), train_X_scaled.max())

# 복원 확인
train_X_restored = mm_X.inverse_transform(train_X_scaled)
print("Restored train_X range:", train_X_restored.min(), train_X_restored.max())
# Out:
# Original train_X range: Wind_Temperature_Interaction        9.096000
# Wind_humidity_Interaction          19.440000
# Temp_Humidity_Interaction        1649.510575
# Temp_Difference                   -17.574581
# Humidity_Difference               -40.060000
# Rainfall_Humidity_Interaction       0.000000
# server_power                       13.597867
# outside_temperature                26.910000
# outside_humidity                   40.955000
# wind_speed                          0.300000
# rainfall                            0.000000
# inner_temperature                  16.552301
# inner_humidity                     31.216670
# dtype: float64 Wind_Temperature_Interaction      318.818250
# Wind_humidity_Interaction         603.436875
# Temp_Humidity_Interaction        2258.514600
# Temp_Difference                     3.962500
# Humidity_Difference                29.532495
# Rainfall_Humidity_Interaction       0.000000
# server_power                       14.605308
# outside_temperature                37.815000
# outside_humidity                   79.120000
# wind_speed                         10.000000
# rainfall                            0.000000
# inner_temperature                  37.164170
# inner_humidity                     82.916670
# dtype: float64
# Scaled train_X range: 0.0 1.0000000000000002
# Restored train_X range: -40.06 2258.5146

# %%
from tensorflow.keras.callbacks import EarlyStopping

# EarlyStopping 설정
early_stopping = EarlyStopping(
    monitor='val_loss',       # Validation Loss를 모니터링
    patience=30,              # 개선되지 않는 에포크 수 (5번 기다림)
    restore_best_weights=True # 가장 낮은 Validation Loss에서의 가중치 복원
)

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

# # ReduceLROnPlateau 설정
lr_decay = ReduceLROnPlateau(
    monitor='val_loss',       # Validation Loss를 기준으로 Learning Rate 감소
    factor=0.8,               # Learning Rate를 50%로 줄임
    patience=15,               # 개선되지 않는 에포크 수 (5번 기다림)
    min_lr=1e-5               # Learning Rate의 하한값
)

# %%
model_checkpoint = ModelCheckpoint(
    filepath='Clipped_best_lstm_all_features.keras',  # 저장 경로
    monitor='val_loss',       # 모니터링할 값
    save_best_only=True,      # Best 모델만 저장
    verbose=1
)

# %%
# LSTM 모델 생성
lstm = lstm_model(n_steps=12, n_horizon=1, n_features=train_X_scaled.shape[1], lr=3e-4)

# EarlyStopping 콜백
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# Learning Rate Decay 콜백
lr_decay = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=15, min_lr=1e-5)

# 모델 학습
history = lstm.fit(
    train_ds,
    validation_data=val_ds,
    epochs=300,
    callbacks=[early_stopping, lr_decay, model_checkpoint]  # 콜백 추가
)

# # 테스트 결과 출력
# lstm.evaluate(test_ds)
# Out:
# WARNING:tensorflow:From c:\Users\Yoon\.conda\envs\gpt\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Epoch 1/300
# c:\Users\Yoon\.conda\envs\gpt\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#      93/Unknown 4s 7ms/step - loss: 0.1373 - mae: 0.4496
# c:\Users\Yoon\.conda\envs\gpt\Lib\site-packages\keras\src\trainers\epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 1: val_loss improved from inf to 0.00296, saving model to Clipped_best_lstm_all_features.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1349 - mae: 0.4439 - val_loss: 0.0030 - val_mae: 0.0616 - learning_rate: 3.0000e-04
# Epoch 2/300
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0360 - mae: 0.2094
# Epoch 2: val_loss improved from 0.00296 to 0.00266, saving model to Clipped_best_lstm_all_features.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0350 - mae: 0.2056 - val_loss: 0.0027 - val_mae: 0.0581 - learning_rate: 3.0000e-04
# Epoch 3/300
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0322 - mae: 0.1948
# Epoch 3: val_loss did not improve from 0.00266
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0320 - mae: 0.1938 - val_loss: 0.0027 - val_mae: 0.0575 - learning_rate: 3.0000e-04
# Epoch 4/300
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0309 - mae: 0.1902
# Epoch 4: val_loss improved from 0.00266 to 0.00224, saving model to Clipped_best_lstm_all_features.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0298 - mae: 0.1859 - val_loss: 0.0022 - val_mae: 0.0518 - learning_rate: 3.0000e-04
# Epoch 5/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0263 - mae: 0.1762
# Epoch 5: val_loss improved from 0.00224 to 0.00185, saving model to Clipped_best_lstm_all_features.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0258 - mae: 0.1737 - val_loss: 0.0019 - val_mae: 0.0457 - learning_rate: 3.0000e-04
# Epoch 6/300
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0257 - mae: 0.1725
# Epoch 6: val_loss improved from 0.00185 to 0.00166, saving model to Clipped_best_lstm_all_features.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0255 - mae: 0.1715 - val_loss: 0.0017 - val_mae: 0.0428 - learning_rate: 3.0000e-04
# Epoch 7/300
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0252 - mae: 0.1739
# Epoch 7: val_loss improved from 0.00166 to 0.00161, saving model to Clipped_best_lstm_all_features.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0249 - mae: 0.1724 - val_loss: 0.0016 - val_mae: 0.0419 - learning_rate: 3.0000e-04
# Epoch 8/300
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0219 - mae: 0.1618
# Epoch 8: val_loss improved from 0.00161 to 0.00153, saving model to Clipped_best_lstm_all_features.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0213 - mae: 0.1592 - val_loss: 0.0015 - val_mae: 0.0413 - learning_rate: 3.0000e-04
# Epoch 9/300
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0198 - mae: 0.1535
# Epoch 9: val_loss did not improve from 0.00153
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0195 - mae: 0.1524 - val_loss: 0.0018 - val_mae: 0.0451 - learning_rate: 3.0000e-04
# Epoch 10/300
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0187 - mae: 0.1470
# Epoch 10: val_loss did not improve from 0.00153
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0182 - mae: 0.1443 - val_loss: 0.0019 - val_mae: 0.0479 - learning_rate: 3.0000e-04
# Epoch 11/300
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0173 - mae: 0.1425
# Epoch 11: val_loss did not improve from 0.00153
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0172 - mae: 0.1418 - val_loss: 0.0018 - val_mae: 0.0463 - learning_rate: 3.0000e-04
# Epoch 12/300
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0161 - mae: 0.1408
# Epoch 12: val_loss did not improve from 0.00153
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0157 - mae: 0.1388 - val_loss: 0.0020 - val_mae: 0.0500 - learning_rate: 3.0000e-04
# Epoch 13/300
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0146 - mae: 0.1308
# Epoch 13: val_loss did not improve from 0.00153
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0146 - mae: 0.1306 - val_loss: 0.0019 - val_mae: 0.0482 - learning_rate: 3.0000e-04
# Epoch 14/300
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0131 - mae: 0.1251
# Epoch 14: val_loss did not improve from 0.00153
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0130 - mae: 0.1242 - val_loss: 0.0018 - val_mae: 0.0461 - learning_rate: 3.0000e-04
# Epoch 15/300
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0138 - mae: 0.1274
# Epoch 15: val_loss did not improve from 0.00153
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0137 - mae: 0.1267 - val_loss: 0.0018 - val_mae: 0.0452 - learning_rate: 3.0000e-04
# Epoch 16/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0122 - mae: 0.1178
# Epoch 16: val_loss did not improve from 0.00153
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0120 - mae: 0.1167 - val_loss: 0.0017 - val_mae: 0.0445 - learning_rate: 3.0000e-04
# Epoch 17/300
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0110 - mae: 0.1130
# Epoch 17: val_loss did not improve from 0.00153
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0107 - mae: 0.1115 - val_loss: 0.0016 - val_mae: 0.0435 - learning_rate: 3.0000e-04
# Epoch 18/300
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0107 - mae: 0.1103
# Epoch 18: val_loss improved from 0.00153 to 0.00145, saving model to Clipped_best_lstm_all_features.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0106 - mae: 0.1097 - val_loss: 0.0014 - val_mae: 0.0414 - learning_rate: 3.0000e-04
# Epoch 19/300
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0088 - mae: 0.1011
# Epoch 19: val_loss did not improve from 0.00145
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0088 - mae: 0.1008 - val_loss: 0.0015 - val_mae: 0.0408 - learning_rate: 3.0000e-04
# Epoch 20/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0104 - mae: 0.1093
# Epoch 20: val_loss improved from 0.00145 to 0.00134, saving model to Clipped_best_lstm_all_features.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0102 - mae: 0.1084 - val_loss: 0.0013 - val_mae: 0.0379 - learning_rate: 3.0000e-04
# Epoch 21/300
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0099 - mae: 0.1062
# Epoch 21: val_loss improved from 0.00134 to 0.00121, saving model to Clipped_best_lstm_all_features.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0098 - mae: 0.1054 - val_loss: 0.0012 - val_mae: 0.0358 - learning_rate: 3.0000e-04
# Epoch 22/300
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0091 - mae: 0.1027
# Epoch 22: val_loss improved from 0.00121 to 0.00109, saving model to Clipped_best_lstm_all_features.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0090 - mae: 0.1021 - val_loss: 0.0011 - val_mae: 0.0336 - learning_rate: 3.0000e-04
# Epoch 23/300
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0083 - mae: 0.0970
# Epoch 23: val_loss did not improve from 0.00109
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0082 - mae: 0.0965 - val_loss: 0.0012 - val_mae: 0.0351 - learning_rate: 3.0000e-04
# Epoch 24/300
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0082 - mae: 0.0952
# Epoch 24: val_loss improved from 0.00109 to 0.00105, saving model to Clipped_best_lstm_all_features.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0080 - mae: 0.0938 - val_loss: 0.0010 - val_mae: 0.0318 - learning_rate: 3.0000e-04
# Epoch 25/300
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0071 - mae: 0.0915
# Epoch 25: val_loss improved from 0.00105 to 0.00103, saving model to Clipped_best_lstm_all_features.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0070 - mae: 0.0913 - val_loss: 0.0010 - val_mae: 0.0308 - learning_rate: 3.0000e-04
# Epoch 26/300
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0080 - mae: 0.0966
# Epoch 26: val_loss improved from 0.00103 to 0.00092, saving model to Clipped_best_lstm_all_features.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0079 - mae: 0.0960 - val_loss: 9.1884e-04 - val_mae: 0.0313 - learning_rate: 3.0000e-04
# Epoch 27/300
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0072 - mae: 0.0893
# Epoch 27: val_loss did not improve from 0.00092
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0071 - mae: 0.0892 - val_loss: 0.0010 - val_mae: 0.0319 - learning_rate: 3.0000e-04
# Epoch 28/300
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0068 - mae: 0.0879
# Epoch 28: val_loss did not improve from 0.00092
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0066 - mae: 0.0867 - val_loss: 0.0010 - val_mae: 0.0334 - learning_rate: 3.0000e-04
# Epoch 29/300
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0064 - mae: 0.0846
# Epoch 29: val_loss did not improve from 0.00092
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0062 - mae: 0.0837 - val_loss: 0.0011 - val_mae: 0.0351 - learning_rate: 3.0000e-04
# Epoch 30/300
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0062 - mae: 0.0837
# Epoch 30: val_loss did not improve from 0.00092
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0061 - mae: 0.0829 - val_loss: 0.0010 - val_mae: 0.0335 - learning_rate: 3.0000e-04
# Epoch 31/300
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0055 - mae: 0.0781
# Epoch 31: val_loss did not improve from 0.00092
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0054 - mae: 0.0779 - val_loss: 0.0011 - val_mae: 0.0362 - learning_rate: 3.0000e-04
# Epoch 32/300
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0052 - mae: 0.0781
# Epoch 32: val_loss did not improve from 0.00092
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0051 - mae: 0.0774 - val_loss: 9.6395e-04 - val_mae: 0.0328 - learning_rate: 3.0000e-04
# Epoch 33/300
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0052 - mae: 0.0779
# Epoch 33: val_loss improved from 0.00092 to 0.00089, saving model to Clipped_best_lstm_all_features.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0052 - mae: 0.0772 - val_loss: 8.8832e-04 - val_mae: 0.0312 - learning_rate: 3.0000e-04
# Epoch 34/300
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0053 - mae: 0.0776
# Epoch 34: val_loss did not improve from 0.00089
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0052 - mae: 0.0771 - val_loss: 0.0011 - val_mae: 0.0359 - learning_rate: 3.0000e-04
# Epoch 35/300
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0054 - mae: 0.0791
# Epoch 35: val_loss did not improve from 0.00089
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0053 - mae: 0.0779 - val_loss: 0.0012 - val_mae: 0.0381 - learning_rate: 3.0000e-04
# Epoch 36/300
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0048 - mae: 0.0746
# Epoch 36: val_loss did not improve from 0.00089
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0048 - mae: 0.0737 - val_loss: 0.0014 - val_mae: 0.0406 - learning_rate: 3.0000e-04
# Epoch 37/300
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0045 - mae: 0.0717
# Epoch 37: val_loss did not improve from 0.00089
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0045 - mae: 0.0713 - val_loss: 0.0010 - val_mae: 0.0358 - learning_rate: 3.0000e-04
# Epoch 38/300
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0046 - mae: 0.0723
# Epoch 38: val_loss did not improve from 0.00089
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0046 - mae: 0.0722 - val_loss: 0.0013 - val_mae: 0.0401 - learning_rate: 3.0000e-04
# Epoch 39/300
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0043 - mae: 0.0688
# Epoch 39: val_loss did not improve from 0.00089
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0043 - mae: 0.0687 - val_loss: 0.0016 - val_mae: 0.0430 - learning_rate: 3.0000e-04
# Epoch 40/300
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - mae: 0.0716
# Epoch 40: val_loss did not improve from 0.00089
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0044 - mae: 0.0715 - val_loss: 0.0013 - val_mae: 0.0386 - learning_rate: 3.0000e-04
# Epoch 41/300
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0046 - mae: 0.0727
# Epoch 41: val_loss did not improve from 0.00089
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0045 - mae: 0.0719 - val_loss: 0.0014 - val_mae: 0.0402 - learning_rate: 3.0000e-04
# Epoch 42/300
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - mae: 0.0717
# Epoch 42: val_loss did not improve from 0.00089
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0044 - mae: 0.0711 - val_loss: 9.2934e-04 - val_mae: 0.0308 - learning_rate: 1.5000e-04
# Epoch 43/300
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047 - mae: 0.0738
# Epoch 43: val_loss did not improve from 0.00089
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0047 - mae: 0.0737 - val_loss: 9.7181e-04 - val_mae: 0.0298 - learning_rate: 1.5000e-04
# Epoch 44/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0048 - mae: 0.0731
# Epoch 44: val_loss did not improve from 0.00089
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0047 - mae: 0.0726 - val_loss: 9.5341e-04 - val_mae: 0.0295 - learning_rate: 1.5000e-04
# Epoch 45/300
# 86/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051 - mae: 0.0767
# Epoch 45: val_loss did not improve from 0.00089
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0050 - mae: 0.0754 - val_loss: 9.0762e-04 - val_mae: 0.0309 - learning_rate: 1.5000e-04
# Epoch 46/300
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0045 - mae: 0.0708
# Epoch 46: val_loss did not improve from 0.00089
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0045 - mae: 0.0707 - val_loss: 8.9562e-04 - val_mae: 0.0311 - learning_rate: 1.5000e-04
# Epoch 47/300
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0045 - mae: 0.0718
# Epoch 47: val_loss improved from 0.00089 to 0.00086, saving model to Clipped_best_lstm_all_features.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0045 - mae: 0.0710 - val_loss: 8.5968e-04 - val_mae: 0.0309 - learning_rate: 1.5000e-04
# Epoch 48/300
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - mae: 0.0701
# Epoch 48: val_loss improved from 0.00086 to 0.00077, saving model to Clipped_best_lstm_all_features.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0044 - mae: 0.0694 - val_loss: 7.7493e-04 - val_mae: 0.0294 - learning_rate: 1.5000e-04
# Epoch 49/300
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0043 - mae: 0.0694
# Epoch 49: val_loss did not improve from 0.00077
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0042 - mae: 0.0687 - val_loss: 0.0010 - val_mae: 0.0341 - learning_rate: 1.5000e-04
# Epoch 50/300
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0040 - mae: 0.0662
# Epoch 50: val_loss did not improve from 0.00077
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0039 - mae: 0.0654 - val_loss: 8.7886e-04 - val_mae: 0.0319 - learning_rate: 1.5000e-04
# Epoch 51/300
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0042 - mae: 0.0670
# Epoch 51: val_loss did not improve from 0.00077
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0041 - mae: 0.0666 - val_loss: 0.0012 - val_mae: 0.0377 - learning_rate: 1.5000e-04
# Epoch 52/300
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - mae: 0.0662
# Epoch 52: val_loss did not improve from 0.00077
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0039 - mae: 0.0661 - val_loss: 0.0011 - val_mae: 0.0357 - learning_rate: 1.5000e-04
# Epoch 53/300
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0036 - mae: 0.0641
# Epoch 53: val_loss did not improve from 0.00077
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0036 - mae: 0.0634 - val_loss: 0.0010 - val_mae: 0.0348 - learning_rate: 1.5000e-04
# Epoch 54/300
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035 - mae: 0.0623
# Epoch 54: val_loss did not improve from 0.00077
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0035 - mae: 0.0621 - val_loss: 0.0012 - val_mae: 0.0365 - learning_rate: 1.5000e-04
# Epoch 55/300
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0037 - mae: 0.0649
# Epoch 55: val_loss did not improve from 0.00077
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0036 - mae: 0.0648 - val_loss: 0.0012 - val_mae: 0.0378 - learning_rate: 1.5000e-04
# Epoch 56/300
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038 - mae: 0.0653
# Epoch 56: val_loss did not improve from 0.00077
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0038 - mae: 0.0652 - val_loss: 0.0010 - val_mae: 0.0346 - learning_rate: 1.5000e-04
# Epoch 57/300
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0036 - mae: 0.0640
# Epoch 57: val_loss did not improve from 0.00077
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0035 - mae: 0.0638 - val_loss: 0.0013 - val_mae: 0.0388 - learning_rate: 1.5000e-04
# Epoch 58/300
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038 - mae: 0.0643
# Epoch 58: val_loss did not improve from 0.00077
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0037 - mae: 0.0638 - val_loss: 0.0011 - val_mae: 0.0362 - learning_rate: 1.5000e-04
# Epoch 59/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - mae: 0.0657
# Epoch 59: val_loss did not improve from 0.00077
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0039 - mae: 0.0652 - val_loss: 0.0010 - val_mae: 0.0342 - learning_rate: 1.5000e-04
# Epoch 60/300
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0039 - mae: 0.0663
# Epoch 60: val_loss did not improve from 0.00077
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0038 - mae: 0.0654 - val_loss: 9.9052e-04 - val_mae: 0.0347 - learning_rate: 1.5000e-04
# Epoch 61/300
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0039 - mae: 0.0660
# Epoch 61: val_loss did not improve from 0.00077
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0038 - mae: 0.0651 - val_loss: 0.0015 - val_mae: 0.0394 - learning_rate: 1.5000e-04
# Epoch 62/300
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0035 - mae: 0.0636
# Epoch 62: val_loss did not improve from 0.00077
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0035 - mae: 0.0629 - val_loss: 0.0014 - val_mae: 0.0387 - learning_rate: 1.5000e-04
# Epoch 63/300
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0036 - mae: 0.0646
# Epoch 63: val_loss did not improve from 0.00077
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0036 - mae: 0.0645 - val_loss: 0.0013 - val_mae: 0.0385 - learning_rate: 1.5000e-04
# Epoch 64/300
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0035 - mae: 0.0630
# Epoch 64: val_loss did not improve from 0.00077
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0035 - mae: 0.0624 - val_loss: 9.7601e-04 - val_mae: 0.0339 - learning_rate: 7.5000e-05
# Epoch 65/300
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0037 - mae: 0.0649
# Epoch 65: val_loss did not improve from 0.00077
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0036 - mae: 0.0645 - val_loss: 0.0011 - val_mae: 0.0359 - learning_rate: 7.5000e-05
# Epoch 66/300
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0035 - mae: 0.0629
# Epoch 66: val_loss did not improve from 0.00077
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0034 - mae: 0.0623 - val_loss: 0.0010 - val_mae: 0.0344 - learning_rate: 7.5000e-05
# Epoch 67/300
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0034 - mae: 0.0619
# Epoch 67: val_loss did not improve from 0.00077
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0033 - mae: 0.0613 - val_loss: 0.0010 - val_mae: 0.0343 - learning_rate: 7.5000e-05
# Epoch 68/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0034 - mae: 0.0623
# Epoch 68: val_loss did not improve from 0.00077
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0034 - mae: 0.0618 - val_loss: 9.9292e-04 - val_mae: 0.0341 - learning_rate: 7.5000e-05
# Epoch 69/300
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0034 - mae: 0.0615
# Epoch 69: val_loss did not improve from 0.00077
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0034 - mae: 0.0612 - val_loss: 0.0013 - val_mae: 0.0379 - learning_rate: 7.5000e-05
# Epoch 70/300
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033 - mae: 0.0612
# Epoch 70: val_loss did not improve from 0.00077
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0033 - mae: 0.0610 - val_loss: 0.0012 - val_mae: 0.0371 - learning_rate: 7.5000e-05
# Epoch 71/300
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0032 - mae: 0.0593
# Epoch 71: val_loss did not improve from 0.00077
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0032 - mae: 0.0587 - val_loss: 0.0012 - val_mae: 0.0367 - learning_rate: 7.5000e-05
# Epoch 72/300
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033 - mae: 0.0612
# Epoch 72: val_loss did not improve from 0.00077
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0032 - mae: 0.0605 - val_loss: 0.0011 - val_mae: 0.0363 - learning_rate: 7.5000e-05
# Epoch 73/300
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0032 - mae: 0.0596
# Epoch 73: val_loss did not improve from 0.00077
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0032 - mae: 0.0594 - val_loss: 0.0012 - val_mae: 0.0374 - learning_rate: 7.5000e-05
# Epoch 74/300
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0034 - mae: 0.0613
# Epoch 74: val_loss did not improve from 0.00077
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0034 - mae: 0.0606 - val_loss: 0.0012 - val_mae: 0.0375 - learning_rate: 7.5000e-05
# Epoch 75/300
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0031 - mae: 0.0587
# Epoch 75: val_loss did not improve from 0.00077
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0031 - mae: 0.0586 - val_loss: 0.0012 - val_mae: 0.0367 - learning_rate: 7.5000e-05
# Epoch 76/300
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033 - mae: 0.0602
# Epoch 76: val_loss did not improve from 0.00077
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0033 - mae: 0.0596 - val_loss: 0.0012 - val_mae: 0.0375 - learning_rate: 7.5000e-05
# Epoch 77/300
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0031 - mae: 0.0596
# Epoch 77: val_loss did not improve from 0.00077
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0031 - mae: 0.0592 - val_loss: 0.0010 - val_mae: 0.0345 - learning_rate: 7.5000e-05
# Epoch 78/300
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0035 - mae: 0.0618
# Epoch 78: val_loss did not improve from 0.00077
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0034 - mae: 0.0611 - val_loss: 0.0012 - val_mae: 0.0372 - learning_rate: 7.5000e-05

# %%
# import tensorflow as tf

# # GPU 사용 가능한지 확인
# gpus = tf.config.list_physical_devices('GPU')
# if gpus:
#     print(f"사용 가능한 GPU: {gpus}")
# else:
#     print("GPU를 찾을 수 없습니다. CPU를 사용합니다.")

# %%
# !pip uninstall tensorflow
# !pip install tensorflow

# %%
# !pip install tensorflow-gpu==2.6.0

# %%
# !nvcc --version  # CUDA Toolkit 버전 확인

# %%
# 테스트 데이터셋에서 예측 수행
y_pred_scaled = lstm.predict(test_ds)  # (samples, n_horizon) 형태

# y_pred를 (samples, 1)로 변환
y_pred = y_pred_scaled.reshape(-1, 1)  # 2차원으로 변환

# y_pred의 스케일 복원
y_pred = mm_Y.inverse_transform(y_pred)

# y_true를 TensorFlow Dataset에서 추출 및 스케일 복원
y_true_scaled = np.concatenate([y for x, y in test_ds], axis=0)  # (samples, n_horizon)
y_true = y_true_scaled.reshape(-1, 1)  # 2차원으로 변환
y_true = mm_Y.inverse_transform(y_true)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# MAE (Mean Absolute Error)
mae = mean_absolute_error(y_true, y_pred)

# RMSE (Root Mean Squared Error)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))

# MAPE (Mean Absolute Percentage Error)
mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# 성능 결과 출력
print(f"MAE: {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"MAPE: {mape:.2f}%")
# Out:
# MAE: 1.07
# RMSE: 1.42
# MAPE: 8.86%

# %%
import matplotlib.pyplot as plt

# 샘플 수 선택 (테스트 데이터 일부만 시각화)

plt.figure(figsize=(12, 6))

plt.plot(y_true[:100], label="True Values", marker='o')
plt.plot(y_pred[:100], label="Predictions", marker='x')

plt.title("True vs Predicted Cooling Power")
plt.xlabel("Time Steps")
plt.ylabel("Cooling Power")
plt.legend()
plt.grid()
plt.show()

# %%
class PositionEmbedding(tf.keras.layers.Layer):
    def __init__(self, max_len, embed_dim):
        super().__init__()
        self.pos_embedding = tf.keras.layers.Embedding(input_dim=max_len, output_dim=embed_dim)

    def call(self, inputs):
        positions = tf.range(start=0, limit=tf.shape(inputs)[1], delta=1)
        positions = self.pos_embedding(positions)
        return inputs + positions

# %%
model_checkpoint = ModelCheckpoint(
    filepath='Clipped_best_transformer_all_features.keras',  # 저장 경로
    monitor='val_loss',       # 모니터링할 값
    save_best_only=True,      # Best 모델만 저장
    verbose=1
)

# %%
def transformer_model(n_steps, n_horizon, n_features, lr):
    """Creates an optimized Transformer model for time series forecasting."""

    # Clear any previous session
    tf.keras.backend.clear_session()

    # Input Layer
    inputs = tf.keras.layers.Input(shape=(n_steps, n_features))

    # Position Embedding
    position_embedding = PositionEmbedding(max_len=n_steps, embed_dim=n_features)(inputs)

    # Transformer Encoder
    transformer = tf.keras.layers.MultiHeadAttention(num_heads=4, key_dim=64)(position_embedding, position_embedding)
    transformer = tf.keras.layers.LayerNormalization(epsilon=1e-6)(transformer)
    transformer = tf.keras.layers.Dropout(0.1)(transformer)

    # Feed-Forward Network
    ff = tf.keras.layers.Dense(128, activation="relu")(transformer)
    ff = tf.keras.layers.Dropout(0.1)(ff)
    ff = tf.keras.layers.Dense(64, activation="relu")(ff)
    ff = tf.keras.layers.LayerNormalization(epsilon=1e-6)(ff)

    # Global Average Pooling
    pooled = tf.keras.layers.GlobalAveragePooling1D()(ff)

    # Output Layer
    outputs = tf.keras.layers.Dense(n_horizon)(pooled)

    # Build Model
    model = tf.keras.models.Model(inputs=inputs, outputs=outputs, name="transformer")

    # Custom Learning Rate
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate=lr,
        decay_steps=1000,
        decay_rate=0.96,
        staircase=True
    )

    # Compile Model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
                  loss="mse",
                  metrics=["mae"])

    return model

# %%
# EarlyStopping 콜백
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# %%
# LSTM 모델 생성
transformer = transformer_model(n_steps=12, n_horizon=1, n_features=train_X_scaled.shape[1], lr=3e-4)

# EarlyStopping 콜백
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# Learning Rate Decay 콜백
lr_decay = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=15, min_lr=1e-5)

# 모델 학습
history_transformer = transformer.fit(
    train_ds,
    validation_data=val_ds,
    epochs=300,  
    callbacks=[early_stopping, model_checkpoint]# 콜백 추가
)
# Out:
# Epoch 1/300
#      95/Unknown 3s 6ms/step - loss: 0.1050 - mae: 0.2301
# c:\Users\Yoon\.conda\envs\gpt\Lib\site-packages\keras\src\trainers\epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 1: val_loss improved from inf to 0.01961, saving model to Clipped_best_transformer_all_features.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.1044 - mae: 0.2294 - val_loss: 0.0196 - val_mae: 0.1218
# Epoch 2/300
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0280 - mae: 0.1343
# Epoch 2: val_loss improved from 0.01961 to 0.00713, saving model to Clipped_best_transformer_all_features.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0276 - mae: 0.1330 - val_loss: 0.0071 - val_mae: 0.0692
# Epoch 3/300
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0254 - mae: 0.1261
# Epoch 3: val_loss did not improve from 0.00713
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0251 - mae: 0.1254 - val_loss: 0.0075 - val_mae: 0.0729
# Epoch 4/300
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0221 - mae: 0.1173
# Epoch 4: val_loss did not improve from 0.00713
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0217 - mae: 0.1161 - val_loss: 0.0107 - val_mae: 0.0898
# Epoch 5/300
# 85/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0169 - mae: 0.1017
# Epoch 5: val_loss improved from 0.00713 to 0.00375, saving model to Clipped_best_transformer_all_features.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0169 - mae: 0.1011 - val_loss: 0.0037 - val_mae: 0.0482
# Epoch 6/300
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0212 - mae: 0.1147
# Epoch 6: val_loss did not improve from 0.00375
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0211 - mae: 0.1145 - val_loss: 0.0038 - val_mae: 0.0500
# Epoch 7/300
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0163 - mae: 0.1002
# Epoch 7: val_loss did not improve from 0.00375
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0160 - mae: 0.0991 - val_loss: 0.0053 - val_mae: 0.0590
# Epoch 8/300
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0146 - mae: 0.0956
# Epoch 8: val_loss did not improve from 0.00375
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0146 - mae: 0.0954 - val_loss: 0.0046 - val_mae: 0.0545
# Epoch 9/300
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0141 - mae: 0.0947
# Epoch 9: val_loss improved from 0.00375 to 0.00362, saving model to Clipped_best_transformer_all_features.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0141 - mae: 0.0941 - val_loss: 0.0036 - val_mae: 0.0488
# Epoch 10/300
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0143 - mae: 0.0939
# Epoch 10: val_loss did not improve from 0.00362
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0143 - mae: 0.0938 - val_loss: 0.0045 - val_mae: 0.0535
# Epoch 11/300
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mae: 0.0841
# Epoch 11: val_loss improved from 0.00362 to 0.00349, saving model to Clipped_best_transformer_all_features.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0118 - mae: 0.0839 - val_loss: 0.0035 - val_mae: 0.0471
# Epoch 12/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0126 - mae: 0.0873
# Epoch 12: val_loss did not improve from 0.00349
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0125 - mae: 0.0868 - val_loss: 0.0042 - val_mae: 0.0513
# Epoch 13/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0111 - mae: 0.0806
# Epoch 13: val_loss improved from 0.00349 to 0.00308, saving model to Clipped_best_transformer_all_features.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0111 - mae: 0.0803 - val_loss: 0.0031 - val_mae: 0.0441
# Epoch 14/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0105 - mae: 0.0781
# Epoch 14: val_loss did not improve from 0.00308
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0105 - mae: 0.0777 - val_loss: 0.0034 - val_mae: 0.0464
# Epoch 15/300
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0092 - mae: 0.0720
# Epoch 15: val_loss did not improve from 0.00308
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0092 - mae: 0.0718 - val_loss: 0.0042 - val_mae: 0.0507
# Epoch 16/300
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0093 - mae: 0.0725
# Epoch 16: val_loss improved from 0.00308 to 0.00300, saving model to Clipped_best_transformer_all_features.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0092 - mae: 0.0723 - val_loss: 0.0030 - val_mae: 0.0431
# Epoch 17/300
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0086 - mae: 0.0686
# Epoch 17: val_loss did not improve from 0.00300
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0086 - mae: 0.0685 - val_loss: 0.0030 - val_mae: 0.0436
# Epoch 18/300
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0087 - mae: 0.0688
# Epoch 18: val_loss improved from 0.00300 to 0.00240, saving model to Clipped_best_transformer_all_features.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0087 - mae: 0.0688 - val_loss: 0.0024 - val_mae: 0.0379
# Epoch 19/300
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0083 - mae: 0.0667
# Epoch 19: val_loss did not improve from 0.00240
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0083 - mae: 0.0663 - val_loss: 0.0032 - val_mae: 0.0431
# Epoch 20/300
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0076 - mae: 0.0636
# Epoch 20: val_loss improved from 0.00240 to 0.00191, saving model to Clipped_best_transformer_all_features.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0076 - mae: 0.0633 - val_loss: 0.0019 - val_mae: 0.0332
# Epoch 21/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0077 - mae: 0.0640
# Epoch 21: val_loss did not improve from 0.00191
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0077 - mae: 0.0638 - val_loss: 0.0025 - val_mae: 0.0380
# Epoch 22/300
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0076 - mae: 0.0619
# Epoch 22: val_loss did not improve from 0.00191
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0076 - mae: 0.0617 - val_loss: 0.0032 - val_mae: 0.0412
# Epoch 23/300
# 90/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0073 - mae: 0.0612
# Epoch 23: val_loss did not improve from 0.00191
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0073 - mae: 0.0611 - val_loss: 0.0021 - val_mae: 0.0356
# Epoch 24/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0075 - mae: 0.0628
# Epoch 24: val_loss did not improve from 0.00191
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0075 - mae: 0.0626 - val_loss: 0.0022 - val_mae: 0.0350
# Epoch 25/300
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0075 - mae: 0.0619
# Epoch 25: val_loss did not improve from 0.00191
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0075 - mae: 0.0616 - val_loss: 0.0026 - val_mae: 0.0403
# Epoch 26/300
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mae: 0.0601
# Epoch 26: val_loss did not improve from 0.00191
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0070 - mae: 0.0600 - val_loss: 0.0033 - val_mae: 0.0427
# Epoch 27/300
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mae: 0.0598
# Epoch 27: val_loss did not improve from 0.00191
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0069 - mae: 0.0594 - val_loss: 0.0027 - val_mae: 0.0382
# Epoch 28/300
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0067 - mae: 0.0579
# Epoch 28: val_loss did not improve from 0.00191
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0067 - mae: 0.0577 - val_loss: 0.0023 - val_mae: 0.0366
# Epoch 29/300
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mae: 0.0604
# Epoch 29: val_loss did not improve from 0.00191
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0070 - mae: 0.0603 - val_loss: 0.0031 - val_mae: 0.0407
# Epoch 30/300
# 89/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0063 - mae: 0.0572
# Epoch 30: val_loss did not improve from 0.00191
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0063 - mae: 0.0569 - val_loss: 0.0037 - val_mae: 0.0434
# Epoch 31/300
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0063 - mae: 0.0557
# Epoch 31: val_loss did not improve from 0.00191
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0063 - mae: 0.0557 - val_loss: 0.0032 - val_mae: 0.0420
# Epoch 32/300
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0066 - mae: 0.0575
# Epoch 32: val_loss did not improve from 0.00191
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0065 - mae: 0.0572 - val_loss: 0.0036 - val_mae: 0.0438
# Epoch 33/300
# 85/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0065 - mae: 0.0580
# Epoch 33: val_loss did not improve from 0.00191
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0065 - mae: 0.0577 - val_loss: 0.0035 - val_mae: 0.0430
# Epoch 34/300
# 86/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0066 - mae: 0.0577
# Epoch 34: val_loss did not improve from 0.00191
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0065 - mae: 0.0572 - val_loss: 0.0029 - val_mae: 0.0399
# Epoch 35/300
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mae: 0.0607
# Epoch 35: val_loss did not improve from 0.00191
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0071 - mae: 0.0601 - val_loss: 0.0034 - val_mae: 0.0421
# Epoch 36/300
# 86/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mae: 0.0590
# Epoch 36: val_loss did not improve from 0.00191
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0068 - mae: 0.0585 - val_loss: 0.0040 - val_mae: 0.0455
# Epoch 37/300
# 85/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0066 - mae: 0.0576
# Epoch 37: val_loss did not improve from 0.00191
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0065 - mae: 0.0570 - val_loss: 0.0039 - val_mae: 0.0451
# Epoch 38/300
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0065 - mae: 0.0573
# Epoch 38: val_loss did not improve from 0.00191
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0065 - mae: 0.0569 - val_loss: 0.0031 - val_mae: 0.0419
# Epoch 39/300
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mae: 0.0619
# Epoch 39: val_loss did not improve from 0.00191
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0071 - mae: 0.0611 - val_loss: 0.0041 - val_mae: 0.0463
# Epoch 40/300
# 86/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - mae: 0.0609
# Epoch 40: val_loss did not improve from 0.00191
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0069 - mae: 0.0602 - val_loss: 0.0027 - val_mae: 0.0392
# Epoch 41/300
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mae: 0.0592
# Epoch 41: val_loss did not improve from 0.00191
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0069 - mae: 0.0586 - val_loss: 0.0034 - val_mae: 0.0429
# Epoch 42/300
# 94/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0066 - mae: 0.0592
# Epoch 42: val_loss did not improve from 0.00191
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0066 - mae: 0.0590 - val_loss: 0.0034 - val_mae: 0.0443
# Epoch 43/300
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0065 - mae: 0.0572
# Epoch 43: val_loss did not improve from 0.00191
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0064 - mae: 0.0567 - val_loss: 0.0033 - val_mae: 0.0420
# Epoch 44/300
# 92/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - mae: 0.0603
# Epoch 44: val_loss did not improve from 0.00191
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0069 - mae: 0.0600 - val_loss: 0.0035 - val_mae: 0.0435
# Epoch 45/300
# 91/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0063 - mae: 0.0566
# Epoch 45: val_loss did not improve from 0.00191
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0063 - mae: 0.0563 - val_loss: 0.0031 - val_mae: 0.0422
# Epoch 46/300
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0066 - mae: 0.0567
# Epoch 46: val_loss did not improve from 0.00191
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0065 - mae: 0.0563 - val_loss: 0.0040 - val_mae: 0.0452
# Epoch 47/300
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0060 - mae: 0.0548
# Epoch 47: val_loss did not improve from 0.00191
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0060 - mae: 0.0545 - val_loss: 0.0038 - val_mae: 0.0457
# Epoch 48/300
# 93/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0062 - mae: 0.0553
# Epoch 48: val_loss did not improve from 0.00191
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0062 - mae: 0.0552 - val_loss: 0.0040 - val_mae: 0.0479
# Epoch 49/300
# 88/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0061 - mae: 0.0555
# Epoch 49: val_loss did not improve from 0.00191
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0060 - mae: 0.0551 - val_loss: 0.0042 - val_mae: 0.0505
# Epoch 50/300
# 87/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0066 - mae: 0.0584
# Epoch 50: val_loss did not improve from 0.00191
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0065 - mae: 0.0579 - val_loss: 0.0035 - val_mae: 0.0441

# %%
# 테스트 데이터셋에서 예측 수행
y_pred_scaled = transformer.predict(test_ds)  # (samples, n_horizon) 형태

# y_pred를 (samples, 1)로 변환
y_pred = y_pred_scaled.reshape(-1, 1)  # 2차원으로 변환

# y_pred의 스케일 복원
y_pred = mm_Y.inverse_transform(y_pred)

# y_true를 TensorFlow Dataset에서 추출 및 스케일 복원
y_true_scaled = np.concatenate([y for x, y in test_ds], axis=0)  # (samples, n_horizon)
y_true = y_true_scaled.reshape(-1, 1)  # 2차원으로 변환
y_true = mm_Y.inverse_transform(y_true)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# 성능 평가
from sklearn.metrics import mean_absolute_error, mean_squared_error

# MAE (Mean Absolute Error)
mae = mean_absolute_error(y_true, y_pred)

# RMSE (Root Mean Squared Error)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))

# MAPE (Mean Absolute Percentage Error)
mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# 성능 결과 출력
print(f"Transformer Results")
print(f"MAE: {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"MAPE: {mape:.2f}%")
# Out:
# Transformer Results
# MAE: 0.79
# RMSE: 1.06
# MAPE: 6.31%

# %%
# 시각화
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

# 샘플 수 선택 (테스트 데이터 일부만 시각화)
plt.plot(y_true, label="True Values", marker='o', linestyle='-', alpha=0.7)
plt.plot(y_pred, label="Predictions", marker='x', linestyle='--', alpha=0.7)

plt.title("Transformer: True vs Predicted Cooling Power")
plt.xlabel("Time Steps")
plt.ylabel("Cooling Power")
plt.legend()
plt.grid()
plt.show()
